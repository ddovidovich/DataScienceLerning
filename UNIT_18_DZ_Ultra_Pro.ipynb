# %% [markdown]
# <a href="https://colab.research.google.com/github/ddovidovich/DataScienceLerning/blob/main/UNIT_18_DZ_Ultra_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Задание Ultra pro

# %% [markdown]
# Взяв за основу практический ноутбук занятия, постройте трансформер для задачи question answering. Трансформер должен на вход принимать какой-то вопрос, а на выходе генерировать ответ на этот вопрос. Можно использовать любую базу для задачи question answering из tensorflow_datasets, например 'web_questions'.

# %% [markdown]
# ##Импорт библиотек

# %%
# Библиотека датасетов от tensorfolw
import tensorflow_datasets as tfds 

# Библиотека для обучения НС
import tensorflow as tf 

# Модуль отвечает за время и обработку временнЫх переменных
import time 

# Библиотека для работы с массивами
import numpy as np 

# Библиотека для отрисовки графиков и картинок
import matplotlib.pyplot as plt

# %% [markdown]
# ##Загрузка базы

# %%
examples, metadata = tfds.load('cosmos_qa', # Имя датасета
                               with_info=True)  # Вывод информации

# Разделяем на обучающую и тестовую выборки
train_examples, val_examples = examples['train'], examples['test']
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cosmos_qa/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteIEW34U/cosmos_qa-train.tfrecord*...:   0%|      …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteIEW34U/cosmos_qa-validation.tfrecord*...:   0%| …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteIEW34U/cosmos_qa-test.tfrecord*...:   0%|       …
# Dataset cosmos_qa downloaded and prepared to /root/tensorflow_datasets/cosmos_qa/1.0.0. Subsequent calls will reuse this data.

# %%
# Посмотрим информацию о датасете
metadata
# Out:
# tfds.core.DatasetInfo(
#     name='cosmos_qa',
#     full_name='cosmos_qa/1.0.0',
#     description="""
#     Cosmos QA is a large-scale dataset of 35.6K problems that require
#      commonsense-based reading comprehension, formulated as multiple-choice
#      questions. It focuses on reading between the lines over a diverse collection
#      of people's everyday narratives, asking questions concerning on the likely
#      causes or effects of events that require reasoning beyond the exact text
#      spans in the context.
#     """,
#     homepage='https://wilburone.github.io/cosmos/',
#     data_path='/root/tensorflow_datasets/cosmos_qa/1.0.0',
#     file_format=tfrecord,
#     download_size=23.27 MiB,
#     dataset_size=27.09 MiB,
#     features=FeaturesDict({
#         'answer0': Text(shape=(), dtype=string),
#         'answer1': Text(shape=(), dtype=string),
#         'answer2': Text(shape=(), dtype=string),
#         'answer3': Text(shape=(), dtype=string),
#         'context': Text(shape=(), dtype=string),
#         'id': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=4),
#         'question': Text(shape=(), dtype=string),
#     }),
#     supervised_keys=None,
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=6963, num_shards=1>,
#         'train': <SplitInfo num_examples=25262, num_shards=1>,
#         'validation': <SplitInfo num_examples=2985, num_shards=1>,
#     },
#     citation="""@inproceedings{huang-etal-2019-cosmos,
#         title = "Cosmos {QA}: Machine Reading Comprehension with Contextual Commonsense Reasoning",
#         author = "Huang, Lifu  and
#           Le Bras, Ronan  and
#           Bhagavatula, Chandra  and
#           Choi, Yejin",
#         booktitle = "Proceedings of the 2019 Conference on Empirical Methods in Natural Language Processing and the 9th International Joint Conference on Natural Language Processing (EMNLP-IJCNLP)",
#         year = "2019",
#         url = "https://www.aclweb.org/anthology/D19-1243"
#     }""",
# )

# %%
# Посмотрим на структуру данных
for full in train_examples.take(5):
  print(full)
# Out:
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'Shop more at the store'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'Shop at a different store'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'Purchase no items'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b'I went to my favorite Dollar Tree ( 50th and Federal ) in between classes yesterday . Look what I found in the check out aisle this time ! Not a pregnancy test for a buck but still ... They did have six packs of Crystal Geyser H2O for a buck .'>, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3P458N04Q1FLA5CQ1T47A9O3PZF2X1##3Z7EFSHGNAC1U72MOPZFB6TDEONCXB##A3IR7DFEKLLLO##Blog_339843##q2_a1##3K1H3NEY7NDCLIENT60KA43KCCFGD3'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'What will she likely do after finding that deal'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of big government as they are conservative .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of not being in the private sector .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the government employment form .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of the government .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"Well it 's been a busy week in the camp this week , applied for three different jobs , I ' m focusing on Government jobs because that s what I ' ve done for the past fifteen months or so . Government jobs mean bloody selection criteria , selection criteria leads to frustration , frustration leads to anger , anger leads to hate and everyone knows where hate leads to . That image really cracks me up , no one considers the nameless Storm Trooper 's hopes and aspirations .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3R0WOCG21M7GWBGBTDD1MLG3RRODUV##3N2BF7Y2VRSHH3EYWAB7BGAVH5AMHV##A3VVR8NR3ED04C##Blog_1258708##q1_a2##38F60IALAGF7XE0SHWZW2IAIFROT0E'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why does the narrator feel resistance to going into government ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b"They had Bug 's word sprout would be found .">, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'They had an appointment with Bug .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'They had a dentist appointment .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"I was n't really in the mood to , but I decided I better take Bug on a short walk . I come home to find that my front door has blown open and Flash was sitting on my stairs , and Sprout was on the ground darting under the stairs . I herded Flash and Bug inside , and somehow during that 20 seconds Sprout managed to disappear completely . Delightfully I had a dentist appointment in ten minutes so I had to leave instead of looking for her .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3HYV4299H0UNQKNYM5NGWBGZV5C8E5##388U7OUMF8ZX3JLU3A03RN5O576R0H##A3VVR8NR3ED04C##Blog_404324##q1_a2##3VP28W7DUPY9AJNOA4JZJBMBZNIFZB'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why did the narrator not look for sprout ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'My mom cares about her granddaughter .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'She is a selfish grandmother .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'My mom is a caring type of person .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"She went and spent the money without even telling us it was here ! I was so angry . I had plans for the money and now the only thing I got was from my boyfriend and even though that 's really all I care about , my little sister is 7 and she deserves something . My mother did n't even get her anything , not even a cake , but she bought her cigarettes thought , you best believe .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'30OITAWPBSHEIOWH1WD098WVX0C9HS##3OVR4I9USSYTLVN2TTA5QY95R4XQ48##A1SNGSRVSHBGPG##Blog_1509573##q1_a1##3QE4DGPGBTPZLMVU0VZR709EZWRG4P'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why did my mom make the purchase that she did ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'It would feel very tiny with not much space .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'We all take the cosplayers home for a party .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'The cosplayers walked down the stairs of the skyscraper .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"So I got separated from afire 's people and they ended up in this tiny little taxi in the car lane . It was like an Asian clown car , oh man . So I got in and we drove outside the con building and met up with a bunch of GL cosplayers a Kamina , Simon , Nia , and Yoko ) . Outside it was like Baltimore , and suddenly all the cosplayers were on the roof of a huge skyscraper , and they joined hands and jumped off . They landed on their feet holy crap .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'34YWR3PJ288EEV9CM60TRLVOSHA0XQ##3S06PH7KSS239YN7HS9J037UWF61D8##A2JY56TZCEPK3J##Blog_1184690##q1_a1##3P458N04Q3V04UBXLRG727CBIJ9X26'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'What may happen after getting into the tiny taxi ?'>}

# %% [markdown]
# Можно заметить, что на вопросы в данных существует более одного ответа, расположенные в разных полях.

# %%
# Выведем 10 пар вопрос-ответ (только первый ответ)
for full in train_examples.take(10):

  # Чтобы вывести текст в читаемом формате, нужно перевести его в кодировку UTF-8
  print('Вопрос: ', str(full['question'].numpy(), encoding='UTF-8'))
  print('Ответ : ', str(full['answer0'].numpy(), encoding='UTF-8'))
  print()
# Out:
# Вопрос:  What will she likely do after finding that deal
# Ответ :  Shop more at the store
#
# Вопрос:  Why does the narrator feel resistance to going into government ?
# Ответ :  They hate the concept of big government as they are conservative .
#
# Вопрос:  Why did the narrator not look for sprout ?
# Ответ :  They had Bug 's word sprout would be found .
#
# Вопрос:  Why did my mom make the purchase that she did ?
# Ответ :  My mom cares about her granddaughter .
#
# Вопрос:  What may happen after getting into the tiny taxi ?
# Ответ :  None of the above choices .
#
# Вопрос:  What might I do after this event ?
# Ответ :  I will try to reason with her and if that does n't work I just shut up .
#
# Вопрос:  What might be the type of program I am working on ?
# Ответ :  I started a new job and I 've been put in a group to work with throughout the training program .
#
# Вопрос:  What is the narrator describing ?
# Ответ :  None of the above choices .
#
# Вопрос:  What might have been the best thing about my meal ?
# Ответ :  It made me remember another meal that was fabulous .
#
# Вопрос:  What might I be trying to accomplish by fasting ?
# Ответ :  None of the above choices .

# %% [markdown]
# В токенайзер отправим тексты вопросов и ответов.

# %%
# Токенайзер для вопросов, с размером словаря 2**13
tokenizer_qt = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (str(full['question'].numpy(), encoding='UTF-8') for full in train_examples), target_vocab_size=2**13)

# Токенайзер для ответов, с размером словаря 2**13
tokenizer_an = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (str(full['answer0'].numpy(), encoding='UTF-8') for full in train_examples), target_vocab_size=2**13)

# %%
# Размер словаря
print(tokenizer_qt.vocab_size)
print(tokenizer_an.vocab_size)
# Out:
# 8590
# 8914

# %%
# Выведем 1 вопрос в формате индексов
for full in train_examples.take(1):
  print(tokenizer_qt.encode(str(full['question'].numpy(), encoding='UTF-8')))
# Out:
# [3, 40, 55, 48, 25, 24, 516, 39, 1154]

# %%
# Выведем 1 ответ в формате индексов
for full in train_examples.take(1):
  print(tokenizer_an.encode(str(full['question'].numpy(), encoding='UTF-8')))
# Out:
# [5636, 38, 16, 68, 139, 48, 216, 3200, 37, 1285]

# %%
# QUE и ANS это вопросы и ответы
def encode(que, ans):

  # Добавление токенов start и end в текст вопроса
  QUE = [tokenizer_qt.vocab_size] + tokenizer_qt.encode(
      str(que.numpy(), encoding='UTF-8')) + [tokenizer_qt.vocab_size+1]
  
  # Добавление токенов start и end в текст ответа
  ANS = [tokenizer_an.vocab_size] + tokenizer_an.encode(
      str(ans.numpy(), encoding='UTF-8')) + [tokenizer_an.vocab_size+1]
  
  return QUE, ANS

# %%
# Обертка над предыдущей функцией encode()
def tf_encode(full):
  a=full
  question, answer = tf.py_function(encode,            # Функция
                                    [full['question'], # Аргументы 
                                     full['answer0']], 
                                    [tf.int64,         # Типы данных
                                     tf.int64]) 
  question.set_shape([None])
  answer.set_shape([None])

  return question, answer

# %%
# Размер буфера в памяти при подготовке датасета
BUFFER_SIZE = 20000 

# Размер батча
BATCH_SIZE = 64  

# Максимальная длина фраз
MAX_LENGTH = 30

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
    
  return tf.logical_and(tf.size(x) <= max_length, # Маска для значений x
                        tf.size(y) <= max_length) # Маска для значений y

# %%
# Прогоняем тексты через токенайзер
train_dataset = train_examples.map(tf_encode) 

# Убираем длинные фразы
train_dataset = train_dataset.filter(filter_max_length) 

# Грузим в память
train_dataset = train_dataset.cache() 

# Делим на батчи и перемешиваем
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE) 

# Кешируем датасет (это делается для увеличения скорости обучения сети)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE) 

# Преобразуем в формат map
val_dataset = val_examples.map(tf_encode)

# Фильтруем по максимальной длинне
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
# Возьмем первый батч датасета
questions_batch, answers_batch = next(iter(val_dataset))

# Посмотрим что внутри
questions_batch, answers_batch
# Out:
# (<tf.Tensor: shape=(64, 30), dtype=int64, numpy=
#  array([[8590,    4,   25, ...,    0,    0,    0],
#         [8590,    4,   15, ...,    0,    0,    0],
#         [8590,    3,    5, ...,    0,    0,    0],
#         ...,
#         [8590,    4,   23, ...,    0,    0,    0],
#         [8590,    4,   23, ...,    0,    0,    0],
#         [8590,    4,   15, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 26), dtype=int64, numpy=
#  array([[8914,    8,    3, ...,    0,    0,    0],
#         [8914,   36,  132, ...,    0,    0,    0],
#         [8914, 8630, 3376, ...,    0,    0,    0],
#         ...,
#         [8914,   36,   68, ...,    0,    0,    0],
#         [8914,   36,   53, ...,    0,    0,    0],
#         [8914,   50, 7941, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):

  # По формуле рассчитаем аргументы позиционного кодирования
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  
  # Получаем аргументы
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # Чётные индексы будут принимать значение от sin
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # Нечётные индексы будут принимать значение от cos
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  # Добавляем ещё одну размерность
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# Зададим значения 50, 512
pos_encoding = positional_encoding(50, 512)
print(pos_encoding.shape)

# Выведем значения поз. кодирования в виде heatmap
plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 50, 512)

# %% [markdown]
# ##Создание архитектуры трансформера

# %% [markdown]
# Архитектура трансформера стандартная, как на занятии. Мы так же работаем с последовательностями, только раньше мы делали перевод и последовательность португальских слов переводили в последовательность русских, а теперь мы работаем с последовательностями одного языка - вопросами и ответами.

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, 
               d_model = 512, # Максимальная длина предложения
               num_heads = 8, # Количество голов сети
               causal=False,  # Параметр для слоя Attention
               dropout=0.0):  # Значение Dropout

    super(MultiHeadAttention, self).__init__()  # Здесь все головы считаем паралелльно - поэтому attention пробегает и по батчу и по числу голов

    assert d_model % num_heads == 0 # Проверим, что размерность головы - целое цисло
    depth = d_model // num_heads    # Размерность каждой головы внимания  =>>  multi-headed_depth = depth / num_heads
                                    # Заметим, что выходы голов конкатенируются, поэтому их размер в их число раз меньше.
                                    # Поэтому размерность выхода должно совпасть в размерностью входа

    self.w_query = tf.keras.layers.Dense(d_model)                            # Dense для Query  (batch_size , seq_length, depth) 
    self.split_reshape_query = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа query до (batch_size , seq_length, num_heads, multi_headed_depth)  
    self.split_permute_query = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_value = tf.keras.layers.Dense(d_model)                            # Dense для Value  (batch_size , seq_length, depth)
    self.split_reshape_value = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа value до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_value = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_key = tf.keras.layers.Dense(d_model)                              # Dense для Key  (batch_size , seq_length, depth)
    self.split_reshape_key = tf.keras.layers.Reshape((-1,num_heads,depth))   # Слой для решейпа key до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_key = tf.keras.layers.Permute((2,1,3))                # Слой для перестановки размерностей для использования Attention

    self.attention = tf.keras.layers.Attention(causal=causal, dropout=dropout) # Прописываем слой Attention
    self.join_permute_attention = tf.keras.layers.Permute((2,1,3))             # Слой обратной перестановки размерностей
    self.join_reshape_attention = tf.keras.layers.Reshape((-1,d_model))        # Слой обратного решейпа до размернсти модели

    self.dense = tf.keras.layers.Dense(d_model)     # Полносвязный слой

  def call(self, inputs, mask=None, training=None): # Основная рабочая функция

    q = inputs[0]                           # Вытащим входной вектор Query
    v = inputs[1]                           # Вытащим входной вектор Value
    k = inputs[2] if len(inputs) > 2 else v # Вытащим входной вектор Key

    query = self.w_query(q)                   # Прогоним через dense
    query = self.split_reshape_query(query)   # Решейпим
    query = self.split_permute_query(query)   # Переставляем размерность

    value = self.w_value(v)                 # Прогоним через dense
    value = self.split_reshape_value(value) # Решейпим
    value = self.split_permute_value(value) # Переставляем размерность

    key = self.w_key(k)               # Прогоним через dense
    key = self.split_reshape_key(key) # Решейпим
    key = self.split_permute_key(key) # Переставляем размерность

    if mask is not None: # Применим маску если есть 

      if mask[0] is not None:
        mask[0] = tf.keras.layers.Reshape((-1,1))(mask[0])     # Слой для решейпа
        mask[0] = tf.keras.layers.Permute((2,1))(mask[0])      # Слой для перестановки размерностей
      
      if mask[1] is not None:
        mask[1] = tf.keras.layers.Reshape((-1,1))(mask[1])     # Слой для решейпа
        mask[1] = tf.keras.layers.Permute((2,1))(mask[1])      # Слой для перестановки размерностей

    attention = self.attention([query, value, key], mask=mask) # Вычисляем вектор внимания
    attention = self.join_permute_attention(attention)         # Обратно перемешиваем размерности
    attention = self.join_reshape_attention(attention)         # Решейпим до (batch_size , seq_length, depth) 

    x = self.dense(attention) # Выходной dense

    return x

# %%
class EncoderLayer(tf.keras.layers.Layer): 

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout
    
    super(EncoderLayer, self).__init__()

    self.multi_head_attention = MultiHeadAttention(d_model, num_heads)   # Определим слой  MultiHeadAttention
    self.dropout_attention = tf.keras.layers.Dropout(dropout)            # Добавим дропаут
    self.add_attention = tf.keras.layers.Add()                           # Слой для получения resudial связи
    self.layer_norm_attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')               # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                              # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                     # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                    # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

  def call(self, inputs, mask=None, training=None):

    # Входной вектор input размножим до 3 - это query, value, key и отдадим attenton, с маской если есть 
    attention = self.multi_head_attention([inputs,inputs,inputs], mask = [mask,mask]) 
    
    # Уменьшим переобучение дроаутом
    attention = self.dropout_attention(attention, training = training) 
    
    # Сделаем resudial связь - добавим входной вектор
    x = self.add_attention([inputs , attention]) 
    
    # Далее нормализация в масштабах уровня
    x = self.layer_norm_attention(x)  
    # x = inputs

    # Добавим Feed Forward  
    
    # Проходим 1й dense с активашкой relu
    dense = self.dense1(x) 
    
    # Второй dense без активашки т.е. с линейной активационной функцией
    dense = self.dense2(dense)  
    
    # Добавляем дропаут
    dense = self.dropout_dense(dense, training = training)  
    
    # Еще одна resudial связь
    x = self.add_dense([x , dense])  
    
    # Нормализация в масштабах уровня
    x = self.layer_norm_dense(x)  

    return x

# %%
class DecoderLayer(tf.keras.layers.Layer):

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout

    super(DecoderLayer, self).__init__()

    self.multi_head_attention1 =  MultiHeadAttention(d_model, num_heads, causal = True) # Определим слой  MultiHeadAttention
    self.dropout_attention1 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention1 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации

    self.multi_head_attention2 =  MultiHeadAttention(d_model, num_heads)                # Определим слой  MultiHeadAttention 
    self.dropout_attention2 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention2 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации


    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')                         # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                                        # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                               # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                              # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)            # Слой нормализации

  def call(self, inputs, mask=None, training=None):
    
    # Подадим на multi-head attention  Query, Key, Value вектора - здесь это один и тотже вектор
    attention = self.multi_head_attention1([inputs[0],inputs[0],inputs[0]], mask = [mask[0],mask[0]])
    
    # Пробежим дропаут
    attention = self.dropout_attention1(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([inputs[0] , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)
    
    # Второй multi-head attention. Подаем выход предыдущих слоев x и выход от энкодера, маску (если есть)
    attention = self.multi_head_attention2([x, inputs[1],inputs[1]], mask = [mask[0],mask[1]])
    
    # Прогоняем через дропаут
    attention = self.dropout_attention2(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([x , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)

    ## Feed Forward
    
    # 1 dense + relu
    dense = self.dense1(x)

    # 2 dense +linear
    dense = self.dense2(dense)

    # Прогоняем через дропаут
    dense = self.dropout_dense(dense, training = training)

    # Пробросим Resudial-связь
    x = self.add_dense([x , dense])

    # Выполним нормализацию
    x = self.layer_norm_dense(x)

    return x

# %%
class Encoder(tf.keras.layers.Layer):

  def __init__(self, 
               input_vocab_size,                  # Размер словаря
               num_layers = 4,                    # Количество слоев энкодера
               d_model = 512,                     # Максимальная длина предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Encoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True)  
    
    self.pos = positional_encoding(maximum_position_encoding,    # Функция позиционного кодирования
                                   d_model)   
                   
    self.encoder_layers = [ EncoderLayer(d_model = d_model,      # Список Nx слоев кодера
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout) for _ in range(num_layers)]  

    self.dropout = tf.keras.layers.Dropout(dropout)              # Просто дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Входной эмбеддинг  
    x = self.embedding(inputs) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) 
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Прогоняем через дроаут
    x = self.dropout(x, training=training)

    # Входной слой embedding+ Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs)

    # Прогоним через Nx слоев кодера
    for encoder_layer in self.encoder_layers: 
      x = encoder_layer(x, mask = embedding_mask)

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs)

# %%
class Decoder(tf.keras.layers.Layer):

  def __init__(self, 
               target_vocab_size,                 # Размер словаря выходных данных
               num_layers = 4,                    # Количество слоев декодера
               d_model = 512,                     # Максимальный размер предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Decoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True) 
    
    self.pos = positional_encoding(maximum_position_encoding,     # Функция позиционного кодирования
                                   d_model)                     

    self.decoder_layers = [ DecoderLayer(d_model = d_model, 
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout)  for _ in range(num_layers)] # Список Nx слоев декодера 

    self.dropout = tf.keras.layers.Dropout(dropout)               # Слой дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Выполним переход в эмбеддинг
    x = self.embedding(inputs[0]) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Просто dropout
    x = self.dropout(x, training=training)
    
    # Входной слой embedding + Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs[0])

    # Прогоним через Nx слоев декодера
    for decoder_layer in self.decoder_layers:
      x = decoder_layer([x,inputs[1]], mask = [embedding_mask, mask])

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs[0])

# %% [markdown]
# ##Обучение трансформера

# %%
num_layers = 4 # Количество слоев
d_model = 128  # Размерность модели
dff = 512      # Максимальная длина предложений
num_heads = 8  # Количество голов

dropout_rate = 0.1 # Значение Dropout

input_vocab_size = tokenizer_qt.vocab_size + 2     # Индекс входного тега
target_vocab_size = tokenizer_an.vocab_size + 3    # Индекс выходного тега


input  = tf.keras.layers.Input(shape=(None,)) # Входной слой для переводимой фразы
target = tf.keras.layers.Input(shape=(None,)) # Вход для перевода

encoder = Encoder(input_vocab_size,           # Создаем энкодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate)  

decoder = Decoder(target_vocab_size,          # Создаем декодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate) 

# Собираем модель 
x = encoder(input)
x = decoder([target, x] , mask = encoder.compute_mask(input))
x = tf.keras.layers.Dense(target_vocab_size)(x)

# Формируем модель, выводим саммери
model = tf.keras.models.Model(inputs=[input, target], outputs=x)
model.summary()
# Out:
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  encoder (Encoder)              (None, None, 128)    1892864     ['input_1[0][0]']
#
#  tf.math.not_equal (TFOpLambda)  (None, None)        0           ['input_1[0][0]']
#
#  decoder (Decoder)              (None, None, 128)    2198656     ['input_2[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'tf.math.not_equal[0][0]']
#
#  dense_64 (Dense)               (None, None, 8917)   1150293     ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 5,241,813
# Trainable params: 5,241,813
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    print('1')
    self.d_model = tf.cast(self.d_model, tf.float16)  # явное приведение к типу данных float64
    print('2')

    self.warmup_steps = warmup_steps
    print('3')

  def __call__(self, step):
    step = tf.cast(step, tf.float16)
    arg1 = tf.math.rsqrt(step)
    print(arg1)
    arg2 = step * (self.warmup_steps ** -1.5)
    print(arg2)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
# Оптимайзер 
optimizer = tf.keras.optimizers.Adam(CustomSchedule(d_model), 
                                     beta_1=0.9, 
                                     beta_2=0.98, 
                                     epsilon=1e-9)
# Out:
# 1
# 2
# 3
# tf.Tensor(inf, shape=(), dtype=float16)
# tf.Tensor(0.0, shape=(), dtype=float16)

# %%
# Функция потерь
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def masked_loss(y_true, y_pred):

  # Считаем маску  
  mask = tf.math.logical_not(tf.math.equal(y_true, 0))
  _loss = loss(y_true, y_pred)

  mask = tf.cast(mask, dtype=_loss.dtype)

  # Накинем маску на потери  
  _loss *= mask

  return tf.reduce_sum(_loss)/tf.reduce_sum(mask)

metrics = [loss, masked_loss, tf.keras.metrics.SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss = loss, metrics = metrics)

# %%
# Количество батчей для обучения
num_batches = 0
for (batch, (_,_)) in enumerate(train_dataset):
  num_batches = batch
print(num_batches)

# Количество батчей для проверки
val_batches = 0
for (batch, (_,_)) in enumerate(val_dataset):
  val_batches = batch
print(val_batches)
# Out:
# 393
# 107

# %% [markdown]
# Обучаем:

# %%
# Создадим генератор данных для обучения
def generator(data_set):
    
  while True:
    for q_batch, a_batch in data_set:
      yield ( [q_batch , a_batch[:, :-1] ] , a_batch[:, 1:] )

# При помощи генератора запускаем обучение
history = model.fit(x = generator(train_dataset),              # Данные для обучения
                    validation_data = generator(val_dataset),  # Данные для проверки
                    epochs=200,                                # Количество эпох
                    steps_per_epoch = num_batches,             # Количество батчей
                    validation_steps = val_batches)            # Батчи на проверку
# Out:
# Epoch 1/200
# Tensor("Rsqrt:0", shape=(), dtype=float16)
# Tensor("mul_1:0", shape=(), dtype=float16)
# Tensor("Rsqrt:0", shape=(), dtype=float16)
# Tensor("mul_1:0", shape=(), dtype=float16)
# 393/393 [==============================] - 124s 211ms/step - loss: 3.4745 - sparse_categorical_crossentropy: 7.7729 - masked_loss: 7.8850 - sparse_categorical_accuracy: 0.1402 - val_loss: 3.0342 - val_sparse_categorical_crossentropy: 6.0942 - val_masked_loss: 6.3280 - val_sparse_categorical_accuracy: 0.2552
# Epoch 2/200
# 393/393 [==============================] - 56s 141ms/step - loss: 2.1070 - sparse_categorical_crossentropy: 4.7320 - masked_loss: 5.1327 - sparse_categorical_accuracy: 0.3730 - val_loss: 2.2713 - val_sparse_categorical_crossentropy: 4.5619 - val_masked_loss: 4.9478 - val_sparse_categorical_accuracy: 0.3297
# Epoch 3/200
# 393/393 [==============================] - 46s 117ms/step - loss: 1.7273 - sparse_categorical_crossentropy: 3.8480 - masked_loss: 4.2502 - sparse_categorical_accuracy: 0.4292 - val_loss: 2.0693 - val_sparse_categorical_crossentropy: 4.1563 - val_masked_loss: 4.5100 - val_sparse_categorical_accuracy: 0.3671
# Epoch 4/200
# 393/393 [==============================] - 42s 107ms/step - loss: 1.5929 - sparse_categorical_crossentropy: 3.5737 - masked_loss: 3.9482 - sparse_categorical_accuracy: 0.4535 - val_loss: 1.9904 - val_sparse_categorical_crossentropy: 3.9979 - val_masked_loss: 4.3382 - val_sparse_categorical_accuracy: 0.3809
# Epoch 5/200
# 393/393 [==============================] - 51s 131ms/step - loss: 1.5272 - sparse_categorical_crossentropy: 3.4250 - masked_loss: 3.7840 - sparse_categorical_accuracy: 0.4671 - val_loss: 1.9507 - val_sparse_categorical_crossentropy: 3.9181 - val_masked_loss: 4.2516 - val_sparse_categorical_accuracy: 0.3881
# Epoch 6/200
# 393/393 [==============================] - 42s 106ms/step - loss: 1.4732 - sparse_categorical_crossentropy: 3.3131 - masked_loss: 3.6603 - sparse_categorical_accuracy: 0.4766 - val_loss: 1.9314 - val_sparse_categorical_crossentropy: 3.8793 - val_masked_loss: 4.2095 - val_sparse_categorical_accuracy: 0.3891
# Epoch 7/200
# 393/393 [==============================] - 43s 109ms/step - loss: 1.4397 - sparse_categorical_crossentropy: 3.2269 - masked_loss: 3.5650 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.9334 - val_sparse_categorical_crossentropy: 3.8834 - val_masked_loss: 4.2139 - val_sparse_categorical_accuracy: 0.3988
# Epoch 8/200
# 393/393 [==============================] - 50s 128ms/step - loss: 1.4056 - sparse_categorical_crossentropy: 3.1495 - masked_loss: 3.4796 - sparse_categorical_accuracy: 0.4905 - val_loss: 1.9296 - val_sparse_categorical_crossentropy: 3.8756 - val_masked_loss: 4.2055 - val_sparse_categorical_accuracy: 0.3948
# Epoch 9/200
# 393/393 [==============================] - 42s 106ms/step - loss: 1.3765 - sparse_categorical_crossentropy: 3.0815 - masked_loss: 3.4038 - sparse_categorical_accuracy: 0.4969 - val_loss: 1.9259 - val_sparse_categorical_crossentropy: 3.8682 - val_masked_loss: 4.1974 - val_sparse_categorical_accuracy: 0.4028
# Epoch 10/200
# 393/393 [==============================] - 43s 110ms/step - loss: 1.3563 - sparse_categorical_crossentropy: 3.0189 - masked_loss: 3.3354 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.9496 - val_sparse_categorical_crossentropy: 3.9159 - val_masked_loss: 4.2491 - val_sparse_categorical_accuracy: 0.3944
# Epoch 11/200
# 393/393 [==============================] - 41s 104ms/step - loss: 1.3203 - sparse_categorical_crossentropy: 2.9626 - masked_loss: 3.2727 - sparse_categorical_accuracy: 0.5058 - val_loss: 1.9357 - val_sparse_categorical_crossentropy: 3.8880 - val_masked_loss: 4.2189 - val_sparse_categorical_accuracy: 0.4001
# Epoch 12/200
# 393/393 [==============================] - 42s 106ms/step - loss: 1.2917 - sparse_categorical_crossentropy: 2.8754 - masked_loss: 3.1769 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.9642 - val_sparse_categorical_crossentropy: 3.9451 - val_masked_loss: 4.2808 - val_sparse_categorical_accuracy: 0.4033
# Epoch 13/200
# 393/393 [==============================] - 41s 106ms/step - loss: 1.2462 - sparse_categorical_crossentropy: 2.7999 - masked_loss: 3.0930 - sparse_categorical_accuracy: 0.5190 - val_loss: 1.9715 - val_sparse_categorical_crossentropy: 3.9598 - val_masked_loss: 4.2968 - val_sparse_categorical_accuracy: 0.3985
# Epoch 14/200
# 393/393 [==============================] - 41s 103ms/step - loss: 1.2083 - sparse_categorical_crossentropy: 2.7088 - masked_loss: 2.9930 - sparse_categorical_accuracy: 0.5268 - val_loss: 1.9995 - val_sparse_categorical_crossentropy: 4.0161 - val_masked_loss: 4.3579 - val_sparse_categorical_accuracy: 0.3982
# Epoch 15/200
# 393/393 [==============================] - 40s 103ms/step - loss: 1.1812 - sparse_categorical_crossentropy: 2.6464 - masked_loss: 2.9233 - sparse_categorical_accuracy: 0.5319 - val_loss: 1.9948 - val_sparse_categorical_crossentropy: 4.0066 - val_masked_loss: 4.3477 - val_sparse_categorical_accuracy: 0.3971
# Epoch 16/200
# 393/393 [==============================] - 50s 128ms/step - loss: 1.1466 - sparse_categorical_crossentropy: 2.5729 - masked_loss: 2.8432 - sparse_categorical_accuracy: 0.5379 - val_loss: 2.0243 - val_sparse_categorical_crossentropy: 4.0659 - val_masked_loss: 4.4120 - val_sparse_categorical_accuracy: 0.3967
# Epoch 17/200
# 393/393 [==============================] - 41s 105ms/step - loss: 1.1215 - sparse_categorical_crossentropy: 2.5161 - masked_loss: 2.7790 - sparse_categorical_accuracy: 0.5427 - val_loss: 2.0472 - val_sparse_categorical_crossentropy: 4.1118 - val_masked_loss: 4.4619 - val_sparse_categorical_accuracy: 0.3924
# Epoch 18/200
# 393/393 [==============================] - 40s 102ms/step - loss: 1.0987 - sparse_categorical_crossentropy: 2.4454 - masked_loss: 2.7017 - sparse_categorical_accuracy: 0.5491 - val_loss: 2.0636 - val_sparse_categorical_crossentropy: 4.1449 - val_masked_loss: 4.4977 - val_sparse_categorical_accuracy: 0.3931
# Epoch 19/200
# 393/393 [==============================] - 43s 108ms/step - loss: 1.0639 - sparse_categorical_crossentropy: 2.3870 - masked_loss: 2.6372 - sparse_categorical_accuracy: 0.5552 - val_loss: 2.0884 - val_sparse_categorical_crossentropy: 4.1945 - val_masked_loss: 4.5516 - val_sparse_categorical_accuracy: 0.3920
# Epoch 20/200
# 393/393 [==============================] - 41s 104ms/step - loss: 1.0419 - sparse_categorical_crossentropy: 2.3270 - masked_loss: 2.5709 - sparse_categorical_accuracy: 0.5602 - val_loss: 2.0958 - val_sparse_categorical_crossentropy: 4.2095 - val_masked_loss: 4.5678 - val_sparse_categorical_accuracy: 0.3920
# Epoch 21/200
# 393/393 [==============================] - 41s 104ms/step - loss: 1.0238 - sparse_categorical_crossentropy: 2.2773 - masked_loss: 2.5158 - sparse_categorical_accuracy: 0.5653 - val_loss: 2.1344 - val_sparse_categorical_crossentropy: 4.2871 - val_masked_loss: 4.6520 - val_sparse_categorical_accuracy: 0.3906
# Epoch 22/200
# 393/393 [==============================] - 43s 108ms/step - loss: 1.0016 - sparse_categorical_crossentropy: 2.2308 - masked_loss: 2.4643 - sparse_categorical_accuracy: 0.5698 - val_loss: 2.1465 - val_sparse_categorical_crossentropy: 4.3114 - val_masked_loss: 4.6784 - val_sparse_categorical_accuracy: 0.3891
# Epoch 23/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.9747 - sparse_categorical_crossentropy: 2.1742 - masked_loss: 2.4019 - sparse_categorical_accuracy: 0.5765 - val_loss: 2.1528 - val_sparse_categorical_crossentropy: 4.3240 - val_masked_loss: 4.6921 - val_sparse_categorical_accuracy: 0.3942
# Epoch 24/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.9467 - sparse_categorical_crossentropy: 2.1321 - masked_loss: 2.3554 - sparse_categorical_accuracy: 0.5803 - val_loss: 2.1620 - val_sparse_categorical_crossentropy: 4.3425 - val_masked_loss: 4.7121 - val_sparse_categorical_accuracy: 0.3921
# Epoch 25/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.9253 - sparse_categorical_crossentropy: 2.0870 - masked_loss: 2.3058 - sparse_categorical_accuracy: 0.5863 - val_loss: 2.1947 - val_sparse_categorical_crossentropy: 4.4081 - val_masked_loss: 4.7834 - val_sparse_categorical_accuracy: 0.3891
# Epoch 26/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.9146 - sparse_categorical_crossentropy: 2.0436 - masked_loss: 2.2578 - sparse_categorical_accuracy: 0.5915 - val_loss: 2.2116 - val_sparse_categorical_crossentropy: 4.4421 - val_masked_loss: 4.8202 - val_sparse_categorical_accuracy: 0.3942
# Epoch 27/200
# 393/393 [==============================] - 82s 209ms/step - loss: 0.9034 - sparse_categorical_crossentropy: 2.0050 - masked_loss: 2.2148 - sparse_categorical_accuracy: 0.5953 - val_loss: 2.2100 - val_sparse_categorical_crossentropy: 4.4390 - val_masked_loss: 4.8169 - val_sparse_categorical_accuracy: 0.3908
# Epoch 28/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.8744 - sparse_categorical_crossentropy: 1.9668 - masked_loss: 2.1727 - sparse_categorical_accuracy: 0.6004 - val_loss: 2.2563 - val_sparse_categorical_crossentropy: 4.5319 - val_masked_loss: 4.9177 - val_sparse_categorical_accuracy: 0.3877
# Epoch 29/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.8650 - sparse_categorical_crossentropy: 1.9324 - masked_loss: 2.1346 - sparse_categorical_accuracy: 0.6044 - val_loss: 2.2482 - val_sparse_categorical_crossentropy: 4.5157 - val_masked_loss: 4.9001 - val_sparse_categorical_accuracy: 0.3891
# Epoch 30/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.8430 - sparse_categorical_crossentropy: 1.8944 - masked_loss: 2.0930 - sparse_categorical_accuracy: 0.6087 - val_loss: 2.2663 - val_sparse_categorical_crossentropy: 4.5519 - val_masked_loss: 4.9394 - val_sparse_categorical_accuracy: 0.3865
# Epoch 31/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.8301 - sparse_categorical_crossentropy: 1.8543 - masked_loss: 2.0491 - sparse_categorical_accuracy: 0.6141 - val_loss: 2.2695 - val_sparse_categorical_crossentropy: 4.5584 - val_masked_loss: 4.9464 - val_sparse_categorical_accuracy: 0.3884
# Epoch 32/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.8194 - sparse_categorical_crossentropy: 1.8257 - masked_loss: 2.0169 - sparse_categorical_accuracy: 0.6180 - val_loss: 2.2938 - val_sparse_categorical_crossentropy: 4.6072 - val_masked_loss: 4.9994 - val_sparse_categorical_accuracy: 0.3871
# Epoch 33/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.7972 - sparse_categorical_crossentropy: 1.7946 - masked_loss: 1.9823 - sparse_categorical_accuracy: 0.6218 - val_loss: 2.3070 - val_sparse_categorical_crossentropy: 4.6338 - val_masked_loss: 5.0283 - val_sparse_categorical_accuracy: 0.3853
# Epoch 34/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.7916 - sparse_categorical_crossentropy: 1.7678 - masked_loss: 1.9529 - sparse_categorical_accuracy: 0.6260 - val_loss: 2.3142 - val_sparse_categorical_crossentropy: 4.6481 - val_masked_loss: 5.0438 - val_sparse_categorical_accuracy: 0.3855
# Epoch 35/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.7753 - sparse_categorical_crossentropy: 1.7351 - masked_loss: 1.9172 - sparse_categorical_accuracy: 0.6308 - val_loss: 2.3499 - val_sparse_categorical_crossentropy: 4.7198 - val_masked_loss: 5.1216 - val_sparse_categorical_accuracy: 0.3858
# Epoch 36/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.7611 - sparse_categorical_crossentropy: 1.7048 - masked_loss: 1.8834 - sparse_categorical_accuracy: 0.6351 - val_loss: 2.3303 - val_sparse_categorical_crossentropy: 4.6805 - val_masked_loss: 5.0789 - val_sparse_categorical_accuracy: 0.3879
# Epoch 37/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.7454 - sparse_categorical_crossentropy: 1.6790 - masked_loss: 1.8548 - sparse_categorical_accuracy: 0.6386 - val_loss: 2.3639 - val_sparse_categorical_crossentropy: 4.7480 - val_masked_loss: 5.1522 - val_sparse_categorical_accuracy: 0.3853
# Epoch 38/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.7378 - sparse_categorical_crossentropy: 1.6572 - masked_loss: 1.8308 - sparse_categorical_accuracy: 0.6415 - val_loss: 2.3768 - val_sparse_categorical_crossentropy: 4.7740 - val_masked_loss: 5.1804 - val_sparse_categorical_accuracy: 0.3869
# Epoch 39/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.7298 - sparse_categorical_crossentropy: 1.6266 - masked_loss: 1.7970 - sparse_categorical_accuracy: 0.6470 - val_loss: 2.3844 - val_sparse_categorical_crossentropy: 4.7891 - val_masked_loss: 5.1968 - val_sparse_categorical_accuracy: 0.3827
# Epoch 40/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.7139 - sparse_categorical_crossentropy: 1.6024 - masked_loss: 1.7705 - sparse_categorical_accuracy: 0.6500 - val_loss: 2.3895 - val_sparse_categorical_crossentropy: 4.7994 - val_masked_loss: 5.2080 - val_sparse_categorical_accuracy: 0.3857
# Epoch 41/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.7078 - sparse_categorical_crossentropy: 1.5854 - masked_loss: 1.7511 - sparse_categorical_accuracy: 0.6532 - val_loss: 2.3985 - val_sparse_categorical_crossentropy: 4.8175 - val_masked_loss: 5.2276 - val_sparse_categorical_accuracy: 0.3847
# Epoch 42/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.6936 - sparse_categorical_crossentropy: 1.5553 - masked_loss: 1.7186 - sparse_categorical_accuracy: 0.6587 - val_loss: 2.4034 - val_sparse_categorical_crossentropy: 4.8273 - val_masked_loss: 5.2383 - val_sparse_categorical_accuracy: 0.3837
# Epoch 43/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.6847 - sparse_categorical_crossentropy: 1.5381 - masked_loss: 1.6994 - sparse_categorical_accuracy: 0.6608 - val_loss: 2.4262 - val_sparse_categorical_crossentropy: 4.8731 - val_masked_loss: 5.2880 - val_sparse_categorical_accuracy: 0.3840
# Epoch 44/200
# 393/393 [==============================] - 50s 129ms/step - loss: 0.6745 - sparse_categorical_crossentropy: 1.5149 - masked_loss: 1.6733 - sparse_categorical_accuracy: 0.6637 - val_loss: 2.4291 - val_sparse_categorical_crossentropy: 4.8789 - val_masked_loss: 5.2942 - val_sparse_categorical_accuracy: 0.3799
# Epoch 45/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.6695 - sparse_categorical_crossentropy: 1.4913 - masked_loss: 1.6477 - sparse_categorical_accuracy: 0.6669 - val_loss: 2.4349 - val_sparse_categorical_crossentropy: 4.8905 - val_masked_loss: 5.3068 - val_sparse_categorical_accuracy: 0.3833
# Epoch 46/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.6584 - sparse_categorical_crossentropy: 1.4724 - masked_loss: 1.6263 - sparse_categorical_accuracy: 0.6713 - val_loss: 2.4498 - val_sparse_categorical_crossentropy: 4.9204 - val_masked_loss: 5.3393 - val_sparse_categorical_accuracy: 0.3860
# Epoch 47/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.6469 - sparse_categorical_crossentropy: 1.4580 - masked_loss: 1.6106 - sparse_categorical_accuracy: 0.6734 - val_loss: 2.4592 - val_sparse_categorical_crossentropy: 4.9394 - val_masked_loss: 5.3599 - val_sparse_categorical_accuracy: 0.3820
# Epoch 48/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.6398 - sparse_categorical_crossentropy: 1.4343 - masked_loss: 1.5847 - sparse_categorical_accuracy: 0.6776 - val_loss: 2.4819 - val_sparse_categorical_crossentropy: 4.9850 - val_masked_loss: 5.4095 - val_sparse_categorical_accuracy: 0.3807
# Epoch 49/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.6319 - sparse_categorical_crossentropy: 1.4162 - masked_loss: 1.5648 - sparse_categorical_accuracy: 0.6810 - val_loss: 2.4734 - val_sparse_categorical_crossentropy: 4.9680 - val_masked_loss: 5.3909 - val_sparse_categorical_accuracy: 0.3838
# Epoch 50/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.6230 - sparse_categorical_crossentropy: 1.3966 - masked_loss: 1.5431 - sparse_categorical_accuracy: 0.6843 - val_loss: 2.4781 - val_sparse_categorical_crossentropy: 4.9774 - val_masked_loss: 5.4011 - val_sparse_categorical_accuracy: 0.3839
# Epoch 51/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.6127 - sparse_categorical_crossentropy: 1.3778 - masked_loss: 1.5224 - sparse_categorical_accuracy: 0.6870 - val_loss: 2.4977 - val_sparse_categorical_crossentropy: 5.0168 - val_masked_loss: 5.4438 - val_sparse_categorical_accuracy: 0.3838
# Epoch 52/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.6097 - sparse_categorical_crossentropy: 1.3712 - masked_loss: 1.5145 - sparse_categorical_accuracy: 0.6874 - val_loss: 2.5058 - val_sparse_categorical_crossentropy: 5.0330 - val_masked_loss: 5.4615 - val_sparse_categorical_accuracy: 0.3843
# Epoch 53/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.6003 - sparse_categorical_crossentropy: 1.3490 - masked_loss: 1.4904 - sparse_categorical_accuracy: 0.6922 - val_loss: 2.5057 - val_sparse_categorical_crossentropy: 5.0328 - val_masked_loss: 5.4613 - val_sparse_categorical_accuracy: 0.3820
# Epoch 54/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5986 - sparse_categorical_crossentropy: 1.3350 - masked_loss: 1.4749 - sparse_categorical_accuracy: 0.6944 - val_loss: 2.5212 - val_sparse_categorical_crossentropy: 5.0640 - val_masked_loss: 5.4951 - val_sparse_categorical_accuracy: 0.3813
# Epoch 55/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.5942 - sparse_categorical_crossentropy: 1.3199 - masked_loss: 1.4580 - sparse_categorical_accuracy: 0.6966 - val_loss: 2.5428 - val_sparse_categorical_crossentropy: 5.1074 - val_masked_loss: 5.5422 - val_sparse_categorical_accuracy: 0.3802
# Epoch 56/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.5784 - sparse_categorical_crossentropy: 1.3016 - masked_loss: 1.4382 - sparse_categorical_accuracy: 0.7011 - val_loss: 2.5424 - val_sparse_categorical_crossentropy: 5.1064 - val_masked_loss: 5.5411 - val_sparse_categorical_accuracy: 0.3830
# Epoch 57/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.5823 - sparse_categorical_crossentropy: 1.2961 - masked_loss: 1.4316 - sparse_categorical_accuracy: 0.7018 - val_loss: 2.5437 - val_sparse_categorical_crossentropy: 5.1091 - val_masked_loss: 5.5440 - val_sparse_categorical_accuracy: 0.3782
# Epoch 58/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5714 - sparse_categorical_crossentropy: 1.2746 - masked_loss: 1.4081 - sparse_categorical_accuracy: 0.7061 - val_loss: 2.5526 - val_sparse_categorical_crossentropy: 5.1270 - val_masked_loss: 5.5635 - val_sparse_categorical_accuracy: 0.3793
# Epoch 59/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.5623 - sparse_categorical_crossentropy: 1.2614 - masked_loss: 1.3939 - sparse_categorical_accuracy: 0.7083 - val_loss: 2.5596 - val_sparse_categorical_crossentropy: 5.1410 - val_masked_loss: 5.5787 - val_sparse_categorical_accuracy: 0.3802
# Epoch 60/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.5587 - sparse_categorical_crossentropy: 1.2475 - masked_loss: 1.3781 - sparse_categorical_accuracy: 0.7105 - val_loss: 2.5673 - val_sparse_categorical_crossentropy: 5.1566 - val_masked_loss: 5.5956 - val_sparse_categorical_accuracy: 0.3778
# Epoch 61/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.5540 - sparse_categorical_crossentropy: 1.2414 - masked_loss: 1.3717 - sparse_categorical_accuracy: 0.7125 - val_loss: 2.5680 - val_sparse_categorical_crossentropy: 5.1579 - val_masked_loss: 5.5970 - val_sparse_categorical_accuracy: 0.3796
# Epoch 62/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.5474 - sparse_categorical_crossentropy: 1.2245 - masked_loss: 1.3526 - sparse_categorical_accuracy: 0.7143 - val_loss: 2.5770 - val_sparse_categorical_crossentropy: 5.1760 - val_masked_loss: 5.6166 - val_sparse_categorical_accuracy: 0.3791
# Epoch 63/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.5398 - sparse_categorical_crossentropy: 1.2146 - masked_loss: 1.3418 - sparse_categorical_accuracy: 0.7165 - val_loss: 2.5884 - val_sparse_categorical_crossentropy: 5.1990 - val_masked_loss: 5.6416 - val_sparse_categorical_accuracy: 0.3797
# Epoch 64/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.5378 - sparse_categorical_crossentropy: 1.1938 - masked_loss: 1.3188 - sparse_categorical_accuracy: 0.7217 - val_loss: 2.6031 - val_sparse_categorical_crossentropy: 5.2285 - val_masked_loss: 5.6736 - val_sparse_categorical_accuracy: 0.3782
# Epoch 65/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.5283 - sparse_categorical_crossentropy: 1.1864 - masked_loss: 1.3107 - sparse_categorical_accuracy: 0.7228 - val_loss: 2.6052 - val_sparse_categorical_crossentropy: 5.2327 - val_masked_loss: 5.6781 - val_sparse_categorical_accuracy: 0.3782
# Epoch 66/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.5273 - sparse_categorical_crossentropy: 1.1787 - masked_loss: 1.3023 - sparse_categorical_accuracy: 0.7236 - val_loss: 2.6113 - val_sparse_categorical_crossentropy: 5.2449 - val_masked_loss: 5.6914 - val_sparse_categorical_accuracy: 0.3775
# Epoch 67/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.5234 - sparse_categorical_crossentropy: 1.1716 - masked_loss: 1.2941 - sparse_categorical_accuracy: 0.7244 - val_loss: 2.6155 - val_sparse_categorical_crossentropy: 5.2532 - val_masked_loss: 5.7004 - val_sparse_categorical_accuracy: 0.3775
# Epoch 68/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.5152 - sparse_categorical_crossentropy: 1.1511 - masked_loss: 1.2719 - sparse_categorical_accuracy: 0.7287 - val_loss: 2.6236 - val_sparse_categorical_crossentropy: 5.2696 - val_masked_loss: 5.7182 - val_sparse_categorical_accuracy: 0.3778
# Epoch 69/200
# 393/393 [==============================] - 82s 210ms/step - loss: 0.5084 - sparse_categorical_crossentropy: 1.1418 - masked_loss: 1.2617 - sparse_categorical_accuracy: 0.7306 - val_loss: 2.6289 - val_sparse_categorical_crossentropy: 5.2803 - val_masked_loss: 5.7298 - val_sparse_categorical_accuracy: 0.3791
# Epoch 70/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.5059 - sparse_categorical_crossentropy: 1.1348 - masked_loss: 1.2536 - sparse_categorical_accuracy: 0.7324 - val_loss: 2.6360 - val_sparse_categorical_crossentropy: 5.2945 - val_masked_loss: 5.7452 - val_sparse_categorical_accuracy: 0.3771
# Epoch 71/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.5066 - sparse_categorical_crossentropy: 1.1229 - masked_loss: 1.2404 - sparse_categorical_accuracy: 0.7338 - val_loss: 2.6362 - val_sparse_categorical_crossentropy: 5.2949 - val_masked_loss: 5.7457 - val_sparse_categorical_accuracy: 0.3771
# Epoch 72/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.4960 - sparse_categorical_crossentropy: 1.1151 - masked_loss: 1.2317 - sparse_categorical_accuracy: 0.7359 - val_loss: 2.6381 - val_sparse_categorical_crossentropy: 5.2986 - val_masked_loss: 5.7497 - val_sparse_categorical_accuracy: 0.3774
# Epoch 73/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.4953 - sparse_categorical_crossentropy: 1.1058 - masked_loss: 1.2219 - sparse_categorical_accuracy: 0.7374 - val_loss: 2.6393 - val_sparse_categorical_crossentropy: 5.3012 - val_masked_loss: 5.7525 - val_sparse_categorical_accuracy: 0.3779
# Epoch 74/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.4898 - sparse_categorical_crossentropy: 1.0992 - masked_loss: 1.2143 - sparse_categorical_accuracy: 0.7385 - val_loss: 2.6597 - val_sparse_categorical_crossentropy: 5.3420 - val_masked_loss: 5.7968 - val_sparse_categorical_accuracy: 0.3780
# Epoch 75/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.4826 - sparse_categorical_crossentropy: 1.0842 - masked_loss: 1.1979 - sparse_categorical_accuracy: 0.7419 - val_loss: 2.6596 - val_sparse_categorical_crossentropy: 5.3419 - val_masked_loss: 5.7967 - val_sparse_categorical_accuracy: 0.3743
# Epoch 76/200
# 393/393 [==============================] - 49s 125ms/step - loss: 0.4797 - sparse_categorical_crossentropy: 1.0744 - masked_loss: 1.1869 - sparse_categorical_accuracy: 0.7440 - val_loss: 2.6615 - val_sparse_categorical_crossentropy: 5.3457 - val_masked_loss: 5.8008 - val_sparse_categorical_accuracy: 0.3767
# Epoch 77/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.4779 - sparse_categorical_crossentropy: 1.0694 - masked_loss: 1.1816 - sparse_categorical_accuracy: 0.7457 - val_loss: 2.6745 - val_sparse_categorical_crossentropy: 5.3719 - val_masked_loss: 5.8292 - val_sparse_categorical_accuracy: 0.3756
# Epoch 78/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.4744 - sparse_categorical_crossentropy: 1.0563 - masked_loss: 1.1673 - sparse_categorical_accuracy: 0.7488 - val_loss: 2.6795 - val_sparse_categorical_crossentropy: 5.3820 - val_masked_loss: 5.8401 - val_sparse_categorical_accuracy: 0.3746
# Epoch 79/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.4682 - sparse_categorical_crossentropy: 1.0521 - masked_loss: 1.1623 - sparse_categorical_accuracy: 0.7486 - val_loss: 2.6740 - val_sparse_categorical_crossentropy: 5.3708 - val_masked_loss: 5.8280 - val_sparse_categorical_accuracy: 0.3764
# Epoch 80/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.4679 - sparse_categorical_crossentropy: 1.0457 - masked_loss: 1.1553 - sparse_categorical_accuracy: 0.7500 - val_loss: 2.6756 - val_sparse_categorical_crossentropy: 5.3741 - val_masked_loss: 5.8316 - val_sparse_categorical_accuracy: 0.3788
# Epoch 81/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.4607 - sparse_categorical_crossentropy: 1.0378 - masked_loss: 1.1465 - sparse_categorical_accuracy: 0.7519 - val_loss: 2.6860 - val_sparse_categorical_crossentropy: 5.3949 - val_masked_loss: 5.8542 - val_sparse_categorical_accuracy: 0.3773
# Epoch 82/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.4600 - sparse_categorical_crossentropy: 1.0269 - masked_loss: 1.1343 - sparse_categorical_accuracy: 0.7535 - val_loss: 2.6984 - val_sparse_categorical_crossentropy: 5.4198 - val_masked_loss: 5.8812 - val_sparse_categorical_accuracy: 0.3783
# Epoch 83/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.4515 - sparse_categorical_crossentropy: 1.0213 - masked_loss: 1.1284 - sparse_categorical_accuracy: 0.7551 - val_loss: 2.6978 - val_sparse_categorical_crossentropy: 5.4186 - val_masked_loss: 5.8799 - val_sparse_categorical_accuracy: 0.3741
# Epoch 84/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.4537 - sparse_categorical_crossentropy: 1.0106 - masked_loss: 1.1166 - sparse_categorical_accuracy: 0.7551 - val_loss: 2.7050 - val_sparse_categorical_crossentropy: 5.4331 - val_masked_loss: 5.8956 - val_sparse_categorical_accuracy: 0.3762
# Epoch 85/200
# 393/393 [==============================] - 49s 125ms/step - loss: 0.4463 - sparse_categorical_crossentropy: 0.9991 - masked_loss: 1.1039 - sparse_categorical_accuracy: 0.7604 - val_loss: 2.7223 - val_sparse_categorical_crossentropy: 5.4679 - val_masked_loss: 5.9334 - val_sparse_categorical_accuracy: 0.3759
# Epoch 86/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.4435 - sparse_categorical_crossentropy: 0.9962 - masked_loss: 1.1007 - sparse_categorical_accuracy: 0.7592 - val_loss: 2.7185 - val_sparse_categorical_crossentropy: 5.4601 - val_masked_loss: 5.9249 - val_sparse_categorical_accuracy: 0.3759
# Epoch 87/200
# 393/393 [==============================] - 82s 208ms/step - loss: 0.4396 - sparse_categorical_crossentropy: 0.9880 - masked_loss: 1.0916 - sparse_categorical_accuracy: 0.7617 - val_loss: 2.7206 - val_sparse_categorical_crossentropy: 5.4644 - val_masked_loss: 5.9296 - val_sparse_categorical_accuracy: 0.3751
# Epoch 88/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.4367 - sparse_categorical_crossentropy: 0.9803 - masked_loss: 1.0830 - sparse_categorical_accuracy: 0.7634 - val_loss: 2.7265 - val_sparse_categorical_crossentropy: 5.4762 - val_masked_loss: 5.9424 - val_sparse_categorical_accuracy: 0.3769
# Epoch 89/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.4336 - sparse_categorical_crossentropy: 0.9717 - masked_loss: 1.0736 - sparse_categorical_accuracy: 0.7647 - val_loss: 2.7287 - val_sparse_categorical_crossentropy: 5.4808 - val_masked_loss: 5.9473 - val_sparse_categorical_accuracy: 0.3776
# Epoch 90/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.4343 - sparse_categorical_crossentropy: 0.9700 - masked_loss: 1.0715 - sparse_categorical_accuracy: 0.7657 - val_loss: 2.7446 - val_sparse_categorical_crossentropy: 5.5126 - val_masked_loss: 5.9819 - val_sparse_categorical_accuracy: 0.3749
# Epoch 91/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.4263 - sparse_categorical_crossentropy: 0.9585 - masked_loss: 1.0591 - sparse_categorical_accuracy: 0.7681 - val_loss: 2.7428 - val_sparse_categorical_crossentropy: 5.5090 - val_masked_loss: 5.9779 - val_sparse_categorical_accuracy: 0.3772
# Epoch 92/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.4260 - sparse_categorical_crossentropy: 0.9549 - masked_loss: 1.0550 - sparse_categorical_accuracy: 0.7680 - val_loss: 2.7609 - val_sparse_categorical_crossentropy: 5.5454 - val_masked_loss: 6.0175 - val_sparse_categorical_accuracy: 0.3742
# Epoch 93/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.4224 - sparse_categorical_crossentropy: 0.9463 - masked_loss: 1.0455 - sparse_categorical_accuracy: 0.7710 - val_loss: 2.7523 - val_sparse_categorical_crossentropy: 5.5281 - val_masked_loss: 5.9987 - val_sparse_categorical_accuracy: 0.3777
# Epoch 94/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.4176 - sparse_categorical_crossentropy: 0.9406 - masked_loss: 1.0392 - sparse_categorical_accuracy: 0.7726 - val_loss: 2.7678 - val_sparse_categorical_crossentropy: 5.5592 - val_masked_loss: 6.0325 - val_sparse_categorical_accuracy: 0.3769
# Epoch 95/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.4164 - sparse_categorical_crossentropy: 0.9331 - masked_loss: 1.0310 - sparse_categorical_accuracy: 0.7735 - val_loss: 2.7588 - val_sparse_categorical_crossentropy: 5.5411 - val_masked_loss: 6.0128 - val_sparse_categorical_accuracy: 0.3758
# Epoch 96/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.4161 - sparse_categorical_crossentropy: 0.9305 - masked_loss: 1.0279 - sparse_categorical_accuracy: 0.7747 - val_loss: 2.7769 - val_sparse_categorical_crossentropy: 5.5774 - val_masked_loss: 6.0522 - val_sparse_categorical_accuracy: 0.3781
# Epoch 97/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.4115 - sparse_categorical_crossentropy: 0.9184 - masked_loss: 1.0151 - sparse_categorical_accuracy: 0.7769 - val_loss: 2.7787 - val_sparse_categorical_crossentropy: 5.5811 - val_masked_loss: 6.0562 - val_sparse_categorical_accuracy: 0.3737
# Epoch 98/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.4112 - sparse_categorical_crossentropy: 0.9186 - masked_loss: 1.0142 - sparse_categorical_accuracy: 0.7759 - val_loss: 2.7837 - val_sparse_categorical_crossentropy: 5.5911 - val_masked_loss: 6.0671 - val_sparse_categorical_accuracy: 0.3746
# Epoch 99/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.4079 - sparse_categorical_crossentropy: 0.9099 - masked_loss: 1.0055 - sparse_categorical_accuracy: 0.7776 - val_loss: 2.7980 - val_sparse_categorical_crossentropy: 5.6198 - val_masked_loss: 6.0982 - val_sparse_categorical_accuracy: 0.3741
# Epoch 100/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.4045 - sparse_categorical_crossentropy: 0.9068 - masked_loss: 1.0018 - sparse_categorical_accuracy: 0.7790 - val_loss: 2.7893 - val_sparse_categorical_crossentropy: 5.6025 - val_masked_loss: 6.0794 - val_sparse_categorical_accuracy: 0.3740
# Epoch 101/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.4040 - sparse_categorical_crossentropy: 0.9044 - masked_loss: 0.9994 - sparse_categorical_accuracy: 0.7790 - val_loss: 2.7956 - val_sparse_categorical_crossentropy: 5.6151 - val_masked_loss: 6.0931 - val_sparse_categorical_accuracy: 0.3748
# Epoch 102/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.3997 - sparse_categorical_crossentropy: 0.8949 - masked_loss: 0.9886 - sparse_categorical_accuracy: 0.7815 - val_loss: 2.8073 - val_sparse_categorical_crossentropy: 5.6385 - val_masked_loss: 6.1185 - val_sparse_categorical_accuracy: 0.3748
# Epoch 103/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.3929 - sparse_categorical_crossentropy: 0.8845 - masked_loss: 0.9775 - sparse_categorical_accuracy: 0.7836 - val_loss: 2.8218 - val_sparse_categorical_crossentropy: 5.6676 - val_masked_loss: 6.1501 - val_sparse_categorical_accuracy: 0.3751
# Epoch 104/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.3959 - sparse_categorical_crossentropy: 0.8855 - masked_loss: 0.9782 - sparse_categorical_accuracy: 0.7834 - val_loss: 2.8061 - val_sparse_categorical_crossentropy: 5.6361 - val_masked_loss: 6.1159 - val_sparse_categorical_accuracy: 0.3713
# Epoch 105/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3915 - sparse_categorical_crossentropy: 0.8784 - masked_loss: 0.9706 - sparse_categorical_accuracy: 0.7847 - val_loss: 2.8102 - val_sparse_categorical_crossentropy: 5.6444 - val_masked_loss: 6.1248 - val_sparse_categorical_accuracy: 0.3757
# Epoch 106/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.3925 - sparse_categorical_crossentropy: 0.8754 - masked_loss: 0.9671 - sparse_categorical_accuracy: 0.7850 - val_loss: 2.8205 - val_sparse_categorical_crossentropy: 5.6650 - val_masked_loss: 6.1473 - val_sparse_categorical_accuracy: 0.3729
# Epoch 107/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.3875 - sparse_categorical_crossentropy: 0.8675 - masked_loss: 0.9586 - sparse_categorical_accuracy: 0.7874 - val_loss: 2.8149 - val_sparse_categorical_crossentropy: 5.6539 - val_masked_loss: 6.1352 - val_sparse_categorical_accuracy: 0.3738
# Epoch 108/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.3884 - sparse_categorical_crossentropy: 0.8646 - masked_loss: 0.9553 - sparse_categorical_accuracy: 0.7881 - val_loss: 2.8385 - val_sparse_categorical_crossentropy: 5.7012 - val_masked_loss: 6.1865 - val_sparse_categorical_accuracy: 0.3712
# Epoch 109/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3860 - sparse_categorical_crossentropy: 0.8622 - masked_loss: 0.9523 - sparse_categorical_accuracy: 0.7885 - val_loss: 2.8311 - val_sparse_categorical_crossentropy: 5.6864 - val_masked_loss: 6.1705 - val_sparse_categorical_accuracy: 0.3744
# Epoch 110/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3795 - sparse_categorical_crossentropy: 0.8570 - masked_loss: 0.9469 - sparse_categorical_accuracy: 0.7899 - val_loss: 2.8339 - val_sparse_categorical_crossentropy: 5.6920 - val_masked_loss: 6.1765 - val_sparse_categorical_accuracy: 0.3739
# Epoch 111/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3785 - sparse_categorical_crossentropy: 0.8477 - masked_loss: 0.9365 - sparse_categorical_accuracy: 0.7916 - val_loss: 2.8323 - val_sparse_categorical_crossentropy: 5.6887 - val_masked_loss: 6.1730 - val_sparse_categorical_accuracy: 0.3738
# Epoch 112/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.3781 - sparse_categorical_crossentropy: 0.8462 - masked_loss: 0.9351 - sparse_categorical_accuracy: 0.7917 - val_loss: 2.8271 - val_sparse_categorical_crossentropy: 5.6783 - val_masked_loss: 6.1617 - val_sparse_categorical_accuracy: 0.3722
# Epoch 113/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3750 - sparse_categorical_crossentropy: 0.8405 - masked_loss: 0.9288 - sparse_categorical_accuracy: 0.7934 - val_loss: 2.8443 - val_sparse_categorical_crossentropy: 5.7130 - val_masked_loss: 6.1993 - val_sparse_categorical_accuracy: 0.3738
# Epoch 114/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.3755 - sparse_categorical_crossentropy: 0.8407 - masked_loss: 0.9288 - sparse_categorical_accuracy: 0.7922 - val_loss: 2.8473 - val_sparse_categorical_crossentropy: 5.7189 - val_masked_loss: 6.2058 - val_sparse_categorical_accuracy: 0.3742
# Epoch 115/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.3679 - sparse_categorical_crossentropy: 0.8244 - masked_loss: 0.9110 - sparse_categorical_accuracy: 0.7973 - val_loss: 2.8424 - val_sparse_categorical_crossentropy: 5.7091 - val_masked_loss: 6.1951 - val_sparse_categorical_accuracy: 0.3735
# Epoch 116/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.3698 - sparse_categorical_crossentropy: 0.8280 - masked_loss: 0.9146 - sparse_categorical_accuracy: 0.7951 - val_loss: 2.8541 - val_sparse_categorical_crossentropy: 5.7326 - val_masked_loss: 6.2206 - val_sparse_categorical_accuracy: 0.3735
# Epoch 117/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.3653 - sparse_categorical_crossentropy: 0.8209 - masked_loss: 0.9069 - sparse_categorical_accuracy: 0.7982 - val_loss: 2.8591 - val_sparse_categorical_crossentropy: 5.7426 - val_masked_loss: 6.2314 - val_sparse_categorical_accuracy: 0.3730
# Epoch 118/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.3626 - sparse_categorical_crossentropy: 0.8112 - masked_loss: 0.8967 - sparse_categorical_accuracy: 0.7991 - val_loss: 2.8705 - val_sparse_categorical_crossentropy: 5.7655 - val_masked_loss: 6.2563 - val_sparse_categorical_accuracy: 0.3728
# Epoch 119/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.3645 - sparse_categorical_crossentropy: 0.8159 - masked_loss: 0.9011 - sparse_categorical_accuracy: 0.7992 - val_loss: 2.8615 - val_sparse_categorical_crossentropy: 5.7475 - val_masked_loss: 6.2368 - val_sparse_categorical_accuracy: 0.3713
# Epoch 120/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.3577 - sparse_categorical_crossentropy: 0.8031 - masked_loss: 0.8873 - sparse_categorical_accuracy: 0.8021 - val_loss: 2.8759 - val_sparse_categorical_crossentropy: 5.7764 - val_masked_loss: 6.2681 - val_sparse_categorical_accuracy: 0.3743
# Epoch 121/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3614 - sparse_categorical_crossentropy: 0.8100 - masked_loss: 0.8950 - sparse_categorical_accuracy: 0.8006 - val_loss: 2.8764 - val_sparse_categorical_crossentropy: 5.7774 - val_masked_loss: 6.2692 - val_sparse_categorical_accuracy: 0.3709
# Epoch 122/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3584 - sparse_categorical_crossentropy: 0.8014 - masked_loss: 0.8854 - sparse_categorical_accuracy: 0.8020 - val_loss: 2.8809 - val_sparse_categorical_crossentropy: 5.7863 - val_masked_loss: 6.2789 - val_sparse_categorical_accuracy: 0.3734
# Epoch 123/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3562 - sparse_categorical_crossentropy: 0.7948 - masked_loss: 0.8784 - sparse_categorical_accuracy: 0.8036 - val_loss: 2.8737 - val_sparse_categorical_crossentropy: 5.7720 - val_masked_loss: 6.2634 - val_sparse_categorical_accuracy: 0.3725
# Epoch 124/200
# 393/393 [==============================] - 82s 210ms/step - loss: 0.3514 - sparse_categorical_crossentropy: 0.7924 - masked_loss: 0.8753 - sparse_categorical_accuracy: 0.8041 - val_loss: 2.8663 - val_sparse_categorical_crossentropy: 5.7570 - val_masked_loss: 6.2471 - val_sparse_categorical_accuracy: 0.3754
# Epoch 125/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3515 - sparse_categorical_crossentropy: 0.7893 - masked_loss: 0.8722 - sparse_categorical_accuracy: 0.8047 - val_loss: 2.8934 - val_sparse_categorical_crossentropy: 5.8114 - val_masked_loss: 6.3061 - val_sparse_categorical_accuracy: 0.3714
# Epoch 126/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3501 - sparse_categorical_crossentropy: 0.7859 - masked_loss: 0.8682 - sparse_categorical_accuracy: 0.8055 - val_loss: 2.8889 - val_sparse_categorical_crossentropy: 5.8024 - val_masked_loss: 6.2963 - val_sparse_categorical_accuracy: 0.3734
# Epoch 127/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.3482 - sparse_categorical_crossentropy: 0.7793 - masked_loss: 0.8611 - sparse_categorical_accuracy: 0.8066 - val_loss: 2.8891 - val_sparse_categorical_crossentropy: 5.8029 - val_masked_loss: 6.2969 - val_sparse_categorical_accuracy: 0.3726
# Epoch 128/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.3486 - sparse_categorical_crossentropy: 0.7836 - masked_loss: 0.8657 - sparse_categorical_accuracy: 0.8061 - val_loss: 2.8902 - val_sparse_categorical_crossentropy: 5.8051 - val_masked_loss: 6.2993 - val_sparse_categorical_accuracy: 0.3717
# Epoch 129/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.3451 - sparse_categorical_crossentropy: 0.7749 - masked_loss: 0.8561 - sparse_categorical_accuracy: 0.8079 - val_loss: 2.8887 - val_sparse_categorical_crossentropy: 5.8020 - val_masked_loss: 6.2959 - val_sparse_categorical_accuracy: 0.3727
# Epoch 130/200
# 393/393 [==============================] - 50s 129ms/step - loss: 0.3415 - sparse_categorical_crossentropy: 0.7668 - masked_loss: 0.8474 - sparse_categorical_accuracy: 0.8094 - val_loss: 2.9076 - val_sparse_categorical_crossentropy: 5.8401 - val_masked_loss: 6.3372 - val_sparse_categorical_accuracy: 0.3731
# Epoch 131/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.3475 - sparse_categorical_crossentropy: 0.7689 - masked_loss: 0.8495 - sparse_categorical_accuracy: 0.8095 - val_loss: 2.9057 - val_sparse_categorical_crossentropy: 5.8363 - val_masked_loss: 6.3331 - val_sparse_categorical_accuracy: 0.3734
# Epoch 132/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.3456 - sparse_categorical_crossentropy: 0.7668 - masked_loss: 0.8472 - sparse_categorical_accuracy: 0.8101 - val_loss: 2.8971 - val_sparse_categorical_crossentropy: 5.8189 - val_masked_loss: 6.3142 - val_sparse_categorical_accuracy: 0.3732
# Epoch 133/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3377 - sparse_categorical_crossentropy: 0.7608 - masked_loss: 0.8406 - sparse_categorical_accuracy: 0.8110 - val_loss: 2.9064 - val_sparse_categorical_crossentropy: 5.8376 - val_masked_loss: 6.3346 - val_sparse_categorical_accuracy: 0.3711
# Epoch 134/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3381 - sparse_categorical_crossentropy: 0.7554 - masked_loss: 0.8346 - sparse_categorical_accuracy: 0.8129 - val_loss: 2.9098 - val_sparse_categorical_crossentropy: 5.8445 - val_masked_loss: 6.3420 - val_sparse_categorical_accuracy: 0.3734
# Epoch 135/200
# 393/393 [==============================] - 73s 185ms/step - loss: 0.3339 - sparse_categorical_crossentropy: 0.7542 - masked_loss: 0.8335 - sparse_categorical_accuracy: 0.8124 - val_loss: 2.9191 - val_sparse_categorical_crossentropy: 5.8630 - val_masked_loss: 6.3621 - val_sparse_categorical_accuracy: 0.3717
# Epoch 136/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.3366 - sparse_categorical_crossentropy: 0.7503 - masked_loss: 0.8289 - sparse_categorical_accuracy: 0.8130 - val_loss: 2.9263 - val_sparse_categorical_crossentropy: 5.8775 - val_masked_loss: 6.3778 - val_sparse_categorical_accuracy: 0.3723
# Epoch 137/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3373 - sparse_categorical_crossentropy: 0.7519 - masked_loss: 0.8307 - sparse_categorical_accuracy: 0.8131 - val_loss: 2.9161 - val_sparse_categorical_crossentropy: 5.8572 - val_masked_loss: 6.3558 - val_sparse_categorical_accuracy: 0.3731
# Epoch 138/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3300 - sparse_categorical_crossentropy: 0.7389 - masked_loss: 0.8163 - sparse_categorical_accuracy: 0.8156 - val_loss: 2.9308 - val_sparse_categorical_crossentropy: 5.8867 - val_masked_loss: 6.3877 - val_sparse_categorical_accuracy: 0.3731
# Epoch 139/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.3333 - sparse_categorical_crossentropy: 0.7460 - masked_loss: 0.8242 - sparse_categorical_accuracy: 0.8144 - val_loss: 2.9228 - val_sparse_categorical_crossentropy: 5.8705 - val_masked_loss: 6.3702 - val_sparse_categorical_accuracy: 0.3732
# Epoch 140/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3279 - sparse_categorical_crossentropy: 0.7315 - masked_loss: 0.8083 - sparse_categorical_accuracy: 0.8184 - val_loss: 2.9380 - val_sparse_categorical_crossentropy: 5.9011 - val_masked_loss: 6.4034 - val_sparse_categorical_accuracy: 0.3719
# Epoch 141/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3291 - sparse_categorical_crossentropy: 0.7348 - masked_loss: 0.8119 - sparse_categorical_accuracy: 0.8176 - val_loss: 2.9344 - val_sparse_categorical_crossentropy: 5.8937 - val_masked_loss: 6.3954 - val_sparse_categorical_accuracy: 0.3738
# Epoch 142/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3257 - sparse_categorical_crossentropy: 0.7294 - masked_loss: 0.8061 - sparse_categorical_accuracy: 0.8193 - val_loss: 2.9428 - val_sparse_categorical_crossentropy: 5.9108 - val_masked_loss: 6.4139 - val_sparse_categorical_accuracy: 0.3712
# Epoch 143/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3271 - sparse_categorical_crossentropy: 0.7255 - masked_loss: 0.8015 - sparse_categorical_accuracy: 0.8192 - val_loss: 2.9464 - val_sparse_categorical_crossentropy: 5.9180 - val_masked_loss: 6.4217 - val_sparse_categorical_accuracy: 0.3714
# Epoch 144/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3223 - sparse_categorical_crossentropy: 0.7243 - masked_loss: 0.8001 - sparse_categorical_accuracy: 0.8205 - val_loss: 2.9438 - val_sparse_categorical_crossentropy: 5.9128 - val_masked_loss: 6.4162 - val_sparse_categorical_accuracy: 0.3732
# Epoch 145/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3204 - sparse_categorical_crossentropy: 0.7244 - masked_loss: 0.8002 - sparse_categorical_accuracy: 0.8192 - val_loss: 2.9337 - val_sparse_categorical_crossentropy: 5.8924 - val_masked_loss: 6.3941 - val_sparse_categorical_accuracy: 0.3710
# Epoch 146/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.3214 - sparse_categorical_crossentropy: 0.7190 - masked_loss: 0.7946 - sparse_categorical_accuracy: 0.8206 - val_loss: 2.9503 - val_sparse_categorical_crossentropy: 5.9257 - val_masked_loss: 6.4301 - val_sparse_categorical_accuracy: 0.3710
# Epoch 147/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.3188 - sparse_categorical_crossentropy: 0.7127 - masked_loss: 0.7875 - sparse_categorical_accuracy: 0.8221 - val_loss: 2.9571 - val_sparse_categorical_crossentropy: 5.9395 - val_masked_loss: 6.4451 - val_sparse_categorical_accuracy: 0.3738
# Epoch 148/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3174 - sparse_categorical_crossentropy: 0.7112 - masked_loss: 0.7858 - sparse_categorical_accuracy: 0.8217 - val_loss: 2.9462 - val_sparse_categorical_crossentropy: 5.9176 - val_masked_loss: 6.4214 - val_sparse_categorical_accuracy: 0.3710
# Epoch 149/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3164 - sparse_categorical_crossentropy: 0.7099 - masked_loss: 0.7843 - sparse_categorical_accuracy: 0.8231 - val_loss: 2.9551 - val_sparse_categorical_crossentropy: 5.9355 - val_masked_loss: 6.4408 - val_sparse_categorical_accuracy: 0.3716
# Epoch 150/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3160 - sparse_categorical_crossentropy: 0.7085 - masked_loss: 0.7827 - sparse_categorical_accuracy: 0.8234 - val_loss: 2.9441 - val_sparse_categorical_crossentropy: 5.9132 - val_masked_loss: 6.4166 - val_sparse_categorical_accuracy: 0.3695
# Epoch 151/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3185 - sparse_categorical_crossentropy: 0.7049 - masked_loss: 0.7788 - sparse_categorical_accuracy: 0.8244 - val_loss: 2.9561 - val_sparse_categorical_crossentropy: 5.9374 - val_masked_loss: 6.4428 - val_sparse_categorical_accuracy: 0.3719
# Epoch 152/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3117 - sparse_categorical_crossentropy: 0.6995 - masked_loss: 0.7730 - sparse_categorical_accuracy: 0.8252 - val_loss: 2.9597 - val_sparse_categorical_crossentropy: 5.9446 - val_masked_loss: 6.4507 - val_sparse_categorical_accuracy: 0.3744
# Epoch 153/200
# 393/393 [==============================] - 50s 129ms/step - loss: 0.3133 - sparse_categorical_crossentropy: 0.7011 - masked_loss: 0.7743 - sparse_categorical_accuracy: 0.8249 - val_loss: 2.9741 - val_sparse_categorical_crossentropy: 5.9736 - val_masked_loss: 6.4821 - val_sparse_categorical_accuracy: 0.3709
# Epoch 154/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.3090 - sparse_categorical_crossentropy: 0.6949 - masked_loss: 0.7679 - sparse_categorical_accuracy: 0.8265 - val_loss: 2.9562 - val_sparse_categorical_crossentropy: 5.9376 - val_masked_loss: 6.4431 - val_sparse_categorical_accuracy: 0.3712
# Epoch 155/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3111 - sparse_categorical_crossentropy: 0.6960 - masked_loss: 0.7690 - sparse_categorical_accuracy: 0.8263 - val_loss: 2.9630 - val_sparse_categorical_crossentropy: 5.9513 - val_masked_loss: 6.4579 - val_sparse_categorical_accuracy: 0.3717
# Epoch 156/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.3097 - sparse_categorical_crossentropy: 0.6910 - masked_loss: 0.7634 - sparse_categorical_accuracy: 0.8266 - val_loss: 2.9690 - val_sparse_categorical_crossentropy: 5.9634 - val_masked_loss: 6.4710 - val_sparse_categorical_accuracy: 0.3715
# Epoch 157/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.3075 - sparse_categorical_crossentropy: 0.6898 - masked_loss: 0.7621 - sparse_categorical_accuracy: 0.8275 - val_loss: 2.9756 - val_sparse_categorical_crossentropy: 5.9765 - val_masked_loss: 6.4853 - val_sparse_categorical_accuracy: 0.3718
# Epoch 158/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3024 - sparse_categorical_crossentropy: 0.6814 - masked_loss: 0.7530 - sparse_categorical_accuracy: 0.8301 - val_loss: 2.9806 - val_sparse_categorical_crossentropy: 5.9866 - val_masked_loss: 6.4962 - val_sparse_categorical_accuracy: 0.3725
# Epoch 159/200
# 393/393 [==============================] - 40s 102ms/step - loss: 0.3076 - sparse_categorical_crossentropy: 0.6853 - masked_loss: 0.7572 - sparse_categorical_accuracy: 0.8291 - val_loss: 2.9741 - val_sparse_categorical_crossentropy: 5.9736 - val_masked_loss: 6.4821 - val_sparse_categorical_accuracy: 0.3735
# Epoch 160/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.3033 - sparse_categorical_crossentropy: 0.6814 - masked_loss: 0.7530 - sparse_categorical_accuracy: 0.8295 - val_loss: 2.9785 - val_sparse_categorical_crossentropy: 5.9823 - val_masked_loss: 6.4916 - val_sparse_categorical_accuracy: 0.3726
# Epoch 161/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3042 - sparse_categorical_crossentropy: 0.6779 - masked_loss: 0.7493 - sparse_categorical_accuracy: 0.8298 - val_loss: 2.9878 - val_sparse_categorical_crossentropy: 6.0011 - val_masked_loss: 6.5120 - val_sparse_categorical_accuracy: 0.3716
# Epoch 162/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.3048 - sparse_categorical_crossentropy: 0.6783 - masked_loss: 0.7493 - sparse_categorical_accuracy: 0.8309 - val_loss: 2.9845 - val_sparse_categorical_crossentropy: 5.9945 - val_masked_loss: 6.5048 - val_sparse_categorical_accuracy: 0.3698
# Epoch 163/200
# 393/393 [==============================] - 41s 103ms/step - loss: 0.2996 - sparse_categorical_crossentropy: 0.6722 - masked_loss: 0.7426 - sparse_categorical_accuracy: 0.8319 - val_loss: 2.9820 - val_sparse_categorical_crossentropy: 5.9894 - val_masked_loss: 6.4993 - val_sparse_categorical_accuracy: 0.3728
# Epoch 164/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.2960 - sparse_categorical_crossentropy: 0.6689 - masked_loss: 0.7388 - sparse_categorical_accuracy: 0.8322 - val_loss: 2.9947 - val_sparse_categorical_crossentropy: 6.0150 - val_masked_loss: 6.5271 - val_sparse_categorical_accuracy: 0.3711
# Epoch 165/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.2970 - sparse_categorical_crossentropy: 0.6652 - masked_loss: 0.7352 - sparse_categorical_accuracy: 0.8340 - val_loss: 2.9933 - val_sparse_categorical_crossentropy: 6.0122 - val_masked_loss: 6.5240 - val_sparse_categorical_accuracy: 0.3707
# Epoch 166/200
# 393/393 [==============================] - 40s 103ms/step - loss: 0.2961 - sparse_categorical_crossentropy: 0.6643 - masked_loss: 0.7338 - sparse_categorical_accuracy: 0.8332 - val_loss: 3.0038 - val_sparse_categorical_crossentropy: 6.0332 - val_masked_loss: 6.5468 - val_sparse_categorical_accuracy: 0.3722
# Epoch 167/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.2895 - sparse_categorical_crossentropy: 0.6509 - masked_loss: 0.7192 - sparse_categorical_accuracy: 0.8373 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 168/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.2561 - sparse_categorical_crossentropy: 0.5691 - masked_loss: 0.6287 - sparse_categorical_accuracy: 0.8562 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 169/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.2433 - sparse_categorical_crossentropy: 0.5464 - masked_loss: 0.6039 - sparse_categorical_accuracy: 0.8617 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 170/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.2423 - sparse_categorical_crossentropy: 0.5444 - masked_loss: 0.6015 - sparse_categorical_accuracy: 0.8619 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 171/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.2428 - sparse_categorical_crossentropy: 0.5436 - masked_loss: 0.6005 - sparse_categorical_accuracy: 0.8629 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 172/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.2397 - sparse_categorical_crossentropy: 0.5415 - masked_loss: 0.5983 - sparse_categorical_accuracy: 0.8628 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 173/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.2422 - sparse_categorical_crossentropy: 0.5431 - masked_loss: 0.6000 - sparse_categorical_accuracy: 0.8622 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 174/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.2418 - sparse_categorical_crossentropy: 0.5419 - masked_loss: 0.5986 - sparse_categorical_accuracy: 0.8627 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 175/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.2461 - sparse_categorical_crossentropy: 0.5461 - masked_loss: 0.6033 - sparse_categorical_accuracy: 0.8619 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 176/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.2429 - sparse_categorical_crossentropy: 0.5452 - masked_loss: 0.6023 - sparse_categorical_accuracy: 0.8618 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 177/200
# 393/393 [==============================] - 51s 129ms/step - loss: 0.2416 - sparse_categorical_crossentropy: 0.5413 - masked_loss: 0.5983 - sparse_categorical_accuracy: 0.8630 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 178/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2438 - sparse_categorical_crossentropy: 0.5440 - masked_loss: 0.6011 - sparse_categorical_accuracy: 0.8622 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 179/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.2417 - sparse_categorical_crossentropy: 0.5430 - masked_loss: 0.5998 - sparse_categorical_accuracy: 0.8631 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 180/200
# 393/393 [==============================] - 73s 186ms/step - loss: 0.2429 - sparse_categorical_crossentropy: 0.5451 - masked_loss: 0.6024 - sparse_categorical_accuracy: 0.8618 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 181/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2447 - sparse_categorical_crossentropy: 0.5448 - masked_loss: 0.6021 - sparse_categorical_accuracy: 0.8621 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 182/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.2417 - sparse_categorical_crossentropy: 0.5430 - masked_loss: 0.5998 - sparse_categorical_accuracy: 0.8621 - val_loss: 3.0161 - val_sparse_categorical_crossentropy: 6.0580 - val_masked_loss: 6.5737 - val_sparse_categorical_accuracy: 0.3696
# Epoch 183/200
# 246/393 [=================>............] - ETA: 11s - loss: 0.2458 - sparse_categorical_crossentropy: 0.5465 - masked_loss: 0.6041 - sparse_categorical_accuracy: 0.8611

# %% [markdown]
# Prediction

# %%
# Возьмем первые 10 значений данных
for i in range(10):
  translation = [tokenizer_an.vocab_size]

  # Пройдём по каждому токену (максимум 30) и сделаем предикт
  for _ in range(30):
    predict = model.predict([questions_batch[i:i+1],np.asarray([translation])]) # Делаем предикт
    translation.append(np.argmax(predict[-1,-1]))        # Ищем индекс токена
    if translation[-1] == tokenizer_an.vocab_size + 1:  # Если предсказан выходной тег, то заканчиваем цикл
      break
  
  # Запишем реальный ответ
  real_translation = []
  for w in answers_batch[:,1:][i].numpy():
    if w == tokenizer_an.vocab_size + 1:
      break
    real_translation.append(w)

  # Запишем вопрос
  real_text = []
  for w in questions_batch[:,1:][i].numpy():
    if w == tokenizer_an.vocab_size + 1:
      break
    real_text.append(w)
  
  print('Вопрос:             ', tokenizer_qt.decode(real_text))
  print('Реальный ответ:     ', tokenizer_an.decode(real_translation))
  print('Ответ трансформера: ', tokenizer_an.decode(translation[1:-1]))
  print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3978c163fb14> in <cell line: 2>()
#       1 # Возьмем первые 10 значений данных
#       2 for i in range(10):
# ----> 3   translation = [tokenizer_an.vocab_size]
#       4
#       5   # Пройдём по каждому токену (максимум 30) и сделаем предикт
#
# NameError: name 'tokenizer_an' is not defined

# %% [markdown]
# Ответы трансформера близкие по смыслу, но не точные. Данных достаточно мало, но результат не плохой.
