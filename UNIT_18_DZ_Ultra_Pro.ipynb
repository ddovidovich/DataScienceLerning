# %% [markdown]
# <a href="https://colab.research.google.com/github/ddovidovich/DataScienceLerning/blob/main/UNIT_18_DZ_Ultra_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Задание Ultra pro

# %% [markdown]
# Взяв за основу практический ноутбук занятия, постройте трансформер для задачи question answering. Трансформер должен на вход принимать какой-то вопрос, а на выходе генерировать ответ на этот вопрос. Можно использовать любую базу для задачи question answering из tensorflow_datasets, например 'web_questions'.

# %% [markdown]
# ##Импорт библиотек

# %%
# Библиотека датасетов от tensorfolw
import tensorflow_datasets as tfds 

# Библиотека для обучения НС
import tensorflow as tf 

# Модуль отвечает за время и обработку временнЫх переменных
import time 

# Библиотека для работы с массивами
import numpy as np 

# Библиотека для отрисовки графиков и картинок
import matplotlib.pyplot as plt

# %% [markdown]
# ##Загрузка базы

# %%
examples, metadata = tfds.load('cosmos_qa', # Имя датасета
                               with_info=True)  # Вывод информации

# Разделяем на обучающую и тестовую выборки
train_examples, val_examples = examples['train'], examples['test']
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cosmos_qa/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteL2147Z/cosmos_qa-train.tfrecord*...:   0%|      …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteL2147Z/cosmos_qa-validation.tfrecord*...:   0%| …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cosmos_qa/1.0.0.incompleteL2147Z/cosmos_qa-test.tfrecord*...:   0%|       …
# Dataset cosmos_qa downloaded and prepared to /root/tensorflow_datasets/cosmos_qa/1.0.0. Subsequent calls will reuse this data.

# %%
# Посмотрим информацию о датасете
metadata
# Out:
# tfds.core.DatasetInfo(
#     name='cosmos_qa',
#     full_name='cosmos_qa/1.0.0',
#     description="""
#     Cosmos QA is a large-scale dataset of 35.6K problems that require
#      commonsense-based reading comprehension, formulated as multiple-choice
#      questions. It focuses on reading between the lines over a diverse collection
#      of people's everyday narratives, asking questions concerning on the likely
#      causes or effects of events that require reasoning beyond the exact text
#      spans in the context.
#     """,
#     homepage='https://wilburone.github.io/cosmos/',
#     data_path='/root/tensorflow_datasets/cosmos_qa/1.0.0',
#     file_format=tfrecord,
#     download_size=23.27 MiB,
#     dataset_size=27.09 MiB,
#     features=FeaturesDict({
#         'answer0': Text(shape=(), dtype=string),
#         'answer1': Text(shape=(), dtype=string),
#         'answer2': Text(shape=(), dtype=string),
#         'answer3': Text(shape=(), dtype=string),
#         'context': Text(shape=(), dtype=string),
#         'id': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=4),
#         'question': Text(shape=(), dtype=string),
#     }),
#     supervised_keys=None,
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=6963, num_shards=1>,
#         'train': <SplitInfo num_examples=25262, num_shards=1>,
#         'validation': <SplitInfo num_examples=2985, num_shards=1>,
#     },
#     citation="""@inproceedings{huang-etal-2019-cosmos,
#         title = "Cosmos {QA}: Machine Reading Comprehension with Contextual Commonsense Reasoning",
#         author = "Huang, Lifu  and
#           Le Bras, Ronan  and
#           Bhagavatula, Chandra  and
#           Choi, Yejin",
#         booktitle = "Proceedings of the 2019 Conference on Empirical Methods in Natural Language Processing and the 9th International Joint Conference on Natural Language Processing (EMNLP-IJCNLP)",
#         year = "2019",
#         url = "https://www.aclweb.org/anthology/D19-1243"
#     }""",
# )

# %%
# Посмотрим на структуру данных
for full in train_examples.take(5):
  print(full)
# Out:
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'Shop more at the store'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'Shop at a different store'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'Purchase no items'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b'I went to my favorite Dollar Tree ( 50th and Federal ) in between classes yesterday . Look what I found in the check out aisle this time ! Not a pregnancy test for a buck but still ... They did have six packs of Crystal Geyser H2O for a buck .'>, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3P458N04Q1FLA5CQ1T47A9O3PZF2X1##3Z7EFSHGNAC1U72MOPZFB6TDEONCXB##A3IR7DFEKLLLO##Blog_339843##q2_a1##3K1H3NEY7NDCLIENT60KA43KCCFGD3'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'What will she likely do after finding that deal'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of big government as they are conservative .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of not being in the private sector .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the government employment form .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'They hate the concept of the government .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"Well it 's been a busy week in the camp this week , applied for three different jobs , I ' m focusing on Government jobs because that s what I ' ve done for the past fifteen months or so . Government jobs mean bloody selection criteria , selection criteria leads to frustration , frustration leads to anger , anger leads to hate and everyone knows where hate leads to . That image really cracks me up , no one considers the nameless Storm Trooper 's hopes and aspirations .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3R0WOCG21M7GWBGBTDD1MLG3RRODUV##3N2BF7Y2VRSHH3EYWAB7BGAVH5AMHV##A3VVR8NR3ED04C##Blog_1258708##q1_a2##38F60IALAGF7XE0SHWZW2IAIFROT0E'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why does the narrator feel resistance to going into government ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b"They had Bug 's word sprout would be found .">, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'They had an appointment with Bug .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'They had a dentist appointment .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"I was n't really in the mood to , but I decided I better take Bug on a short walk . I come home to find that my front door has blown open and Flash was sitting on my stairs , and Sprout was on the ground darting under the stairs . I herded Flash and Bug inside , and somehow during that 20 seconds Sprout managed to disappear completely . Delightfully I had a dentist appointment in ten minutes so I had to leave instead of looking for her .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'3HYV4299H0UNQKNYM5NGWBGZV5C8E5##388U7OUMF8ZX3JLU3A03RN5O576R0H##A3VVR8NR3ED04C##Blog_404324##q1_a2##3VP28W7DUPY9AJNOA4JZJBMBZNIFZB'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why did the narrator not look for sprout ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'My mom cares about her granddaughter .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'She is a selfish grandmother .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'My mom is a caring type of person .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"She went and spent the money without even telling us it was here ! I was so angry . I had plans for the money and now the only thing I got was from my boyfriend and even though that 's really all I care about , my little sister is 7 and she deserves something . My mother did n't even get her anything , not even a cake , but she bought her cigarettes thought , you best believe .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'30OITAWPBSHEIOWH1WD098WVX0C9HS##3OVR4I9USSYTLVN2TTA5QY95R4XQ48##A1SNGSRVSHBGPG##Blog_1509573##q1_a1##3QE4DGPGBTPZLMVU0VZR709EZWRG4P'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'Why did my mom make the purchase that she did ?'>}
# {'answer0': <tf.Tensor: shape=(), dtype=string, numpy=b'None of the above choices .'>, 'answer1': <tf.Tensor: shape=(), dtype=string, numpy=b'It would feel very tiny with not much space .'>, 'answer2': <tf.Tensor: shape=(), dtype=string, numpy=b'We all take the cosplayers home for a party .'>, 'answer3': <tf.Tensor: shape=(), dtype=string, numpy=b'The cosplayers walked down the stairs of the skyscraper .'>, 'context': <tf.Tensor: shape=(), dtype=string, numpy=b"So I got separated from afire 's people and they ended up in this tiny little taxi in the car lane . It was like an Asian clown car , oh man . So I got in and we drove outside the con building and met up with a bunch of GL cosplayers a Kamina , Simon , Nia , and Yoko ) . Outside it was like Baltimore , and suddenly all the cosplayers were on the roof of a huge skyscraper , and they joined hands and jumped off . They landed on their feet holy crap .">, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'34YWR3PJ288EEV9CM60TRLVOSHA0XQ##3S06PH7KSS239YN7HS9J037UWF61D8##A2JY56TZCEPK3J##Blog_1184690##q1_a1##3P458N04Q3V04UBXLRG727CBIJ9X26'>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'What may happen after getting into the tiny taxi ?'>}

# %% [markdown]
# Можно заметить, что на вопросы в данных существует более одного ответа, расположенные в разных полях.

# %%
# Выведем 10 пар вопрос-ответ (только первый ответ)
for full in train_examples.take(10):

  # Чтобы вывести текст в читаемом формате, нужно перевести его в кодировку UTF-8
  print('Вопрос: ', str(full['question'].numpy(), encoding='UTF-8'))
  print('Ответ : ', str(full['answer0'].numpy(), encoding='UTF-8'))
  print()
# Out:
# Вопрос:  What will she likely do after finding that deal
# Ответ :  Shop more at the store
#
# Вопрос:  Why does the narrator feel resistance to going into government ?
# Ответ :  They hate the concept of big government as they are conservative .
#
# Вопрос:  Why did the narrator not look for sprout ?
# Ответ :  They had Bug 's word sprout would be found .
#
# Вопрос:  Why did my mom make the purchase that she did ?
# Ответ :  My mom cares about her granddaughter .
#
# Вопрос:  What may happen after getting into the tiny taxi ?
# Ответ :  None of the above choices .
#
# Вопрос:  What might I do after this event ?
# Ответ :  I will try to reason with her and if that does n't work I just shut up .
#
# Вопрос:  What might be the type of program I am working on ?
# Ответ :  I started a new job and I 've been put in a group to work with throughout the training program .
#
# Вопрос:  What is the narrator describing ?
# Ответ :  None of the above choices .
#
# Вопрос:  What might have been the best thing about my meal ?
# Ответ :  It made me remember another meal that was fabulous .
#
# Вопрос:  What might I be trying to accomplish by fasting ?
# Ответ :  None of the above choices .

# %% [markdown]
# В токенайзер отправим тексты вопросов и ответов.

# %%
# Токенайзер для вопросов и ответов, с размером словаря 2**13
tokenizer_full = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (str(full['question'].numpy() + full['answer0'].numpy(), encoding='UTF-8') for full in train_examples), target_vocab_size=2**13)

# %%
# Размер словаря
print(tokenizer_full.vocab_size)
# Out:
# 7988

# %%
# Выведем 1 вопрос в формате индексов
for full in train_examples.take(1):
  print(tokenizer_full.encode(str(full['question'].numpy(), encoding='UTF-8')))
# Out:
# [4, 32, 64, 67, 34, 40, 881, 45, 1095]

# %%
# Выведем 1 ответ в формате индексов
for full in train_examples.take(1):
  print(tokenizer_full.encode(str(full['answer0'].numpy(), encoding='UTF-8')))
# Out:
# [3121, 673, 115, 46, 1, 350]

# %%
# QUE и ANS это вопросы и ответы
def encode(que, ans):

  # Добавление токенов start и end в текст вопроса
  QUE = [tokenizer_full.vocab_size] + tokenizer_full.encode(
      str(que.numpy(), encoding='UTF-8')) + [tokenizer_full.vocab_size+1]
  
  # Добавление токенов start и end в текст ответа
  ANS = [tokenizer_full.vocab_size] + tokenizer_full.encode(
      str(ans.numpy(), encoding='UTF-8')) + [tokenizer_full.vocab_size+1]
  
  return QUE, ANS

# %%
# Обертка над предыдущей функцией encode()
def tf_encode(full):
  a=full
  question, answer = tf.py_function(encode,            # Функция
                                    [full['question'], # Аргументы 
                                     full['answer0']], 
                                    [tf.int64,         # Типы данных
                                     tf.int64]) 
  question.set_shape([None])
  answer.set_shape([None])

  return question, answer

# %%
# Размер буфера в памяти при подготовке датасета
BUFFER_SIZE = 20000 

# Размер батча
BATCH_SIZE = 64  

# Максимальная длина фраз
MAX_LENGTH = 30

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
    
  return tf.logical_and(tf.size(x) <= max_length, # Маска для значений x
                        tf.size(y) <= max_length) # Маска для значений y

# %%
# Прогоняем тексты через токенайзер
train_dataset = train_examples.map(tf_encode) 

# Убираем длинные фразы
train_dataset = train_dataset.filter(filter_max_length) 

# Грузим в память
train_dataset = train_dataset.cache() 

# Делим на батчи и перемешиваем
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE) 

# Кешируем датасет (это делается для увеличения скорости обучения сети)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE) 

# Преобразуем в формат map
val_dataset = val_examples.map(tf_encode)

# Фильтруем по максимальной длинне
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
# Возьмем первый батч датасета
questions_batch, answers_batch = next(iter(val_dataset))

# Посмотрим что внутри
questions_batch, answers_batch
# Out:
# (<tf.Tensor: shape=(64, 24), dtype=int64, numpy=
#  array([[7988,    9,   34, ...,    0,    0,    0],
#         [7988,    9,   24, ...,    0,    0,    0],
#         [7988,    4,   10, ...,    0,    0,    0],
#         ...,
#         [7988,    9,   18, ...,    0,    0,    0],
#         [7988,    9,   24, ...,    0,    0,    0],
#         [7988,    4,   10, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 26), dtype=int64, numpy=
#  array([[7988,   17,    6, ...,    0,    0,    0],
#         [7988,   78,  149, ...,    0,    0,    0],
#         [7988, 5598, 2863, ...,    0,    0,    0],
#         ...,
#         [7988,   78,   91, ...,    0,    0,    0],
#         [7988,  106, 1917, ...,    0,    0,    0],
#         [7988, 2870,  508, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):

  # По формуле рассчитаем аргументы позиционного кодирования
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  
  # Получаем аргументы
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # Чётные индексы будут принимать значение от sin
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # Нечётные индексы будут принимать значение от cos
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  # Добавляем ещё одну размерность
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# Зададим значения 50, 512
pos_encoding = positional_encoding(50, 512)
print(pos_encoding.shape)

# Выведем значения поз. кодирования в виде heatmap
plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 50, 512)

# %% [markdown]
# ##Создание архитектуры трансформера

# %% [markdown]
# Архитектура трансформера стандартная, как на занятии. Мы так же работаем с последовательностями, только раньше мы делали перевод и последовательность португальских слов переводили в последовательность русских, а теперь мы работаем с последовательностями одного языка - вопросами и ответами.

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, 
               d_model = 512, # Максимальная длина предложения
               num_heads = 8, # Количество голов сети
               causal=False,  # Параметр для слоя Attention
               dropout=0.0):  # Значение Dropout

    super(MultiHeadAttention, self).__init__()  # Здесь все головы считаем паралелльно - поэтому attention пробегает и по батчу и по числу голов

    assert d_model % num_heads == 0 # Проверим, что размерность головы - целое цисло
    depth = d_model // num_heads    # Размерность каждой головы внимания  =>>  multi-headed_depth = depth / num_heads
                                    # Заметим, что выходы голов конкатенируются, поэтому их размер в их число раз меньше.
                                    # Поэтому размерность выхода должно совпасть в размерностью входа

    self.w_query = tf.keras.layers.Dense(d_model)                            # Dense для Query  (batch_size , seq_length, depth) 
    self.split_reshape_query = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа query до (batch_size , seq_length, num_heads, multi_headed_depth)  
    self.split_permute_query = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_value = tf.keras.layers.Dense(d_model)                            # Dense для Value  (batch_size , seq_length, depth)
    self.split_reshape_value = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа value до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_value = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_key = tf.keras.layers.Dense(d_model)                              # Dense для Key  (batch_size , seq_length, depth)
    self.split_reshape_key = tf.keras.layers.Reshape((-1,num_heads,depth))   # Слой для решейпа key до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_key = tf.keras.layers.Permute((2,1,3))                # Слой для перестановки размерностей для использования Attention

    self.attention = tf.keras.layers.Attention(causal=causal, dropout=dropout) # Прописываем слой Attention
    self.join_permute_attention = tf.keras.layers.Permute((2,1,3))             # Слой обратной перестановки размерностей
    self.join_reshape_attention = tf.keras.layers.Reshape((-1,d_model))        # Слой обратного решейпа до размернсти модели

    self.dense = tf.keras.layers.Dense(d_model)     # Полносвязный слой

  def call(self, inputs, mask=None, training=None): # Основная рабочая функция

    q = inputs[0]                           # Вытащим входной вектор Query
    v = inputs[1]                           # Вытащим входной вектор Value
    k = inputs[2] if len(inputs) > 2 else v # Вытащим входной вектор Key

    query = self.w_query(q)                   # Прогоним через dense
    query = self.split_reshape_query(query)   # Решейпим
    query = self.split_permute_query(query)   # Переставляем размерность

    value = self.w_value(v)                 # Прогоним через dense
    value = self.split_reshape_value(value) # Решейпим
    value = self.split_permute_value(value) # Переставляем размерность

    key = self.w_key(k)               # Прогоним через dense
    key = self.split_reshape_key(key) # Решейпим
    key = self.split_permute_key(key) # Переставляем размерность

    if mask is not None: # Применим маску если есть 

      if mask[0] is not None:
        mask[0] = tf.keras.layers.Reshape((-1,1))(mask[0])     # Слой для решейпа
        mask[0] = tf.keras.layers.Permute((2,1))(mask[0])      # Слой для перестановки размерностей
      
      if mask[1] is not None:
        mask[1] = tf.keras.layers.Reshape((-1,1))(mask[1])     # Слой для решейпа
        mask[1] = tf.keras.layers.Permute((2,1))(mask[1])      # Слой для перестановки размерностей

    attention = self.attention([query, value, key], mask=mask) # Вычисляем вектор внимания
    attention = self.join_permute_attention(attention)         # Обратно перемешиваем размерности
    attention = self.join_reshape_attention(attention)         # Решейпим до (batch_size , seq_length, depth) 

    x = self.dense(attention) # Выходной dense

    return x

# %%
class EncoderLayer(tf.keras.layers.Layer): 

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout
    
    super(EncoderLayer, self).__init__()

    self.multi_head_attention = MultiHeadAttention(d_model, num_heads)   # Определим слой  MultiHeadAttention
    self.dropout_attention = tf.keras.layers.Dropout(dropout)            # Добавим дропаут
    self.add_attention = tf.keras.layers.Add()                           # Слой для получения resudial связи
    self.layer_norm_attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')               # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                              # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                     # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                    # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

  def call(self, inputs, mask=None, training=None):

    # Входной вектор input размножим до 3 - это query, value, key и отдадим attenton, с маской если есть 
    attention = self.multi_head_attention([inputs,inputs,inputs], mask = [mask,mask]) 
    
    # Уменьшим переобучение дроаутом
    attention = self.dropout_attention(attention, training = training) 
    
    # Сделаем resudial связь - добавим входной вектор
    x = self.add_attention([inputs , attention]) 
    
    # Далее нормализация в масштабах уровня
    x = self.layer_norm_attention(x)  
    # x = inputs

    # Добавим Feed Forward  
    
    # Проходим 1й dense с активашкой relu
    dense = self.dense1(x) 
    
    # Второй dense без активашки т.е. с линейной активационной функцией
    dense = self.dense2(dense)  
    
    # Добавляем дропаут
    dense = self.dropout_dense(dense, training = training)  
    
    # Еще одна resudial связь
    x = self.add_dense([x , dense])  
    
    # Нормализация в масштабах уровня
    x = self.layer_norm_dense(x)  

    return x

# %%
class DecoderLayer(tf.keras.layers.Layer):

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout

    super(DecoderLayer, self).__init__()

    self.multi_head_attention1 =  MultiHeadAttention(d_model, num_heads, causal = True) # Определим слой  MultiHeadAttention
    self.dropout_attention1 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention1 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации

    self.multi_head_attention2 =  MultiHeadAttention(d_model, num_heads)                # Определим слой  MultiHeadAttention 
    self.dropout_attention2 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention2 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации


    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')                         # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                                        # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                               # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                              # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)            # Слой нормализации

  def call(self, inputs, mask=None, training=None):
    
    # Подадим на multi-head attention  Query, Key, Value вектора - здесь это один и тотже вектор
    attention = self.multi_head_attention1([inputs[0],inputs[0],inputs[0]], mask = [mask[0],mask[0]])
    
    # Пробежим дропаут
    attention = self.dropout_attention1(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([inputs[0] , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)
    
    # Второй multi-head attention. Подаем выход предыдущих слоев x и выход от энкодера, маску (если есть)
    attention = self.multi_head_attention2([x, inputs[1],inputs[1]], mask = [mask[0],mask[1]])
    
    # Прогоняем через дропаут
    attention = self.dropout_attention2(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([x , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)

    ## Feed Forward
    
    # 1 dense + relu
    dense = self.dense1(x)

    # 2 dense +linear
    dense = self.dense2(dense)

    # Прогоняем через дропаут
    dense = self.dropout_dense(dense, training = training)

    # Пробросим Resudial-связь
    x = self.add_dense([x , dense])

    # Выполним нормализацию
    x = self.layer_norm_dense(x)

    return x

# %%
class Encoder(tf.keras.layers.Layer):

  def __init__(self, 
               input_vocab_size,                  # Размер словаря
               num_layers = 4,                    # Количество слоев энкодера
               d_model = 512,                     # Максимальная длина предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Encoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True)  
    
    self.pos = positional_encoding(maximum_position_encoding,    # Функция позиционного кодирования
                                   d_model)   
                   
    self.encoder_layers = [ EncoderLayer(d_model = d_model,      # Список Nx слоев кодера
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout) for _ in range(num_layers)]  

    self.dropout = tf.keras.layers.Dropout(dropout)              # Просто дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Входной эмбеддинг  
    x = self.embedding(inputs) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) 
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Прогоняем через дроаут
    x = self.dropout(x, training=training)

    # Входной слой embedding+ Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs)

    # Прогоним через Nx слоев кодера
    for encoder_layer in self.encoder_layers: 
      x = encoder_layer(x, mask = embedding_mask)

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs)

# %%
class Decoder(tf.keras.layers.Layer):

  def __init__(self, 
               target_vocab_size,                 # Размер словаря выходных данных
               num_layers = 4,                    # Количество слоев декодера
               d_model = 512,                     # Максимальный размер предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Decoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True) 
    
    self.pos = positional_encoding(maximum_position_encoding,     # Функция позиционного кодирования
                                   d_model)                     

    self.decoder_layers = [ DecoderLayer(d_model = d_model, 
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout)  for _ in range(num_layers)] # Список Nx слоев декодера 

    self.dropout = tf.keras.layers.Dropout(dropout)               # Слой дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Выполним переход в эмбеддинг
    x = self.embedding(inputs[0]) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Просто dropout
    x = self.dropout(x, training=training)
    
    # Входной слой embedding + Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs[0])

    # Прогоним через Nx слоев декодера
    for decoder_layer in self.decoder_layers:
      x = decoder_layer([x,inputs[1]], mask = [embedding_mask, mask])

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs[0])

# %% [markdown]
# ##Обучение трансформера

# %%
num_layers = 4 # Количество слоев
d_model = 128  # Размерность модели
dff = 512      # Максимальная длина предложений
num_heads = 8  # Количество голов

dropout_rate = 0.1 # Значение Dropout

input_vocab_size = tokenizer_full.vocab_size + 2     # Индекс входного тега
target_vocab_size = tokenizer_full.vocab_size + 3    # Индекс выходного тега


input  = tf.keras.layers.Input(shape=(None,)) # Входной слой для переводимой фразы
target = tf.keras.layers.Input(shape=(None,)) # Вход для перевода

encoder = Encoder(input_vocab_size,           # Создаем энкодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate)  

decoder = Decoder(target_vocab_size,          # Создаем декодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate) 

# Собираем модель 
x = encoder(input)
x = decoder([target, x] , mask = encoder.compute_mask(input))
x = tf.keras.layers.Dense(target_vocab_size)(x)

# Формируем модель, выводим саммери
model = tf.keras.models.Model(inputs=[input, target], outputs=x)
model.summary()
# Out:
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  encoder (Encoder)              (None, None, 128)    1815808     ['input_1[0][0]']
#
#  tf.math.not_equal (TFOpLambda)  (None, None)        0           ['input_1[0][0]']
#
#  decoder (Decoder)              (None, None, 128)    2080128     ['input_2[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'tf.math.not_equal[0][0]']
#
#  dense_64 (Dense)               (None, None, 7991)   1030839     ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 4,926,775
# Trainable params: 4,926,775
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    print('1')
    self.d_model = tf.cast(self.d_model, tf.float16)  # явное приведение к типу данных float64
    print('2')

    self.warmup_steps = warmup_steps
    print('3')

  def __call__(self, step):
    step = tf.cast(step, tf.float16)
    arg1 = tf.math.rsqrt(step)
    print(arg1)
    arg2 = step * (self.warmup_steps ** -1.5)
    print(arg2)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
# Оптимайзер 
optimizer = tf.keras.optimizers.Adam(CustomSchedule(d_model), 
                                     beta_1=0.9, 
                                     beta_2=0.98, 
                                     epsilon=1e-9)
# Out:
# 1
# 2
# 3
# tf.Tensor(inf, shape=(), dtype=float16)
# tf.Tensor(0.0, shape=(), dtype=float16)

# %%
# Функция потерь
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def masked_loss(y_true, y_pred):

  # Считаем маску  
  mask = tf.math.logical_not(tf.math.equal(y_true, 0))
  _loss = loss(y_true, y_pred)

  mask = tf.cast(mask, dtype=_loss.dtype)

  # Накинем маску на потери  
  _loss *= mask

  return tf.reduce_sum(_loss)/tf.reduce_sum(mask)

metrics = [loss, masked_loss, tf.keras.metrics.SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss = loss, metrics = metrics)

# %%
# Количество батчей для обучения
num_batches = 0
for (batch, (_,_)) in enumerate(train_dataset):
  num_batches = batch
print(num_batches)

# Количество батчей для проверки
val_batches = 0
for (batch, (_,_)) in enumerate(val_dataset):
  val_batches = batch
print(val_batches)
# Out:
# 393
# 107

# %% [markdown]
# Обучаем:

# %%
# Создадим генератор данных для обучения
def generator(data_set):
    
  while True:
    for q_batch, a_batch in data_set:
      yield ( [q_batch , a_batch[:, :-1] ] , a_batch[:, 1:] )

# При помощи генератора запускаем обучение
history = model.fit(x = generator(train_dataset),              # Данные для обучения
                    validation_data = generator(val_dataset),  # Данные для проверки
                    epochs=200,                                # Количество эпох
                    steps_per_epoch = num_batches,             # Количество батчей
                    validation_steps = val_batches)            # Батчи на проверку
# Out:
# Epoch 1/200
# Tensor("Rsqrt:0", shape=(), dtype=float16)
# Tensor("mul_1:0", shape=(), dtype=float16)
# Tensor("Rsqrt:0", shape=(), dtype=float16)
# Tensor("mul_1:0", shape=(), dtype=float16)
# 393/393 [==============================] - 134s 227ms/step - loss: 3.4187 - sparse_categorical_crossentropy: 7.6545 - masked_loss: 7.7902 - sparse_categorical_accuracy: 0.1579 - val_loss: 3.0337 - val_sparse_categorical_crossentropy: 6.0381 - val_masked_loss: 6.2986 - val_sparse_categorical_accuracy: 0.2316
# Epoch 2/200
# 393/393 [==============================] - 49s 124ms/step - loss: 2.1242 - sparse_categorical_crossentropy: 4.7414 - masked_loss: 5.1512 - sparse_categorical_accuracy: 0.3628 - val_loss: 2.2913 - val_sparse_categorical_crossentropy: 4.5604 - val_masked_loss: 4.9436 - val_sparse_categorical_accuracy: 0.3248
# Epoch 3/200
# 393/393 [==============================] - 55s 139ms/step - loss: 1.7344 - sparse_categorical_crossentropy: 3.8818 - masked_loss: 4.2788 - sparse_categorical_accuracy: 0.4227 - val_loss: 2.0889 - val_sparse_categorical_crossentropy: 4.1577 - val_masked_loss: 4.5085 - val_sparse_categorical_accuracy: 0.3666
# Epoch 4/200
# 393/393 [==============================] - 45s 114ms/step - loss: 1.6101 - sparse_categorical_crossentropy: 3.6113 - masked_loss: 3.9809 - sparse_categorical_accuracy: 0.4442 - val_loss: 2.0066 - val_sparse_categorical_crossentropy: 3.9938 - val_masked_loss: 4.3309 - val_sparse_categorical_accuracy: 0.3791
# Epoch 5/200
# 393/393 [==============================] - 54s 137ms/step - loss: 1.5354 - sparse_categorical_crossentropy: 3.4547 - masked_loss: 3.8086 - sparse_categorical_accuracy: 0.4590 - val_loss: 1.9734 - val_sparse_categorical_crossentropy: 3.9277 - val_masked_loss: 4.2591 - val_sparse_categorical_accuracy: 0.3863
# Epoch 6/200
# 393/393 [==============================] - 45s 115ms/step - loss: 1.4893 - sparse_categorical_crossentropy: 3.3476 - masked_loss: 3.6909 - sparse_categorical_accuracy: 0.4681 - val_loss: 1.9478 - val_sparse_categorical_crossentropy: 3.8768 - val_masked_loss: 4.2039 - val_sparse_categorical_accuracy: 0.3906
# Epoch 7/200
# 393/393 [==============================] - 44s 112ms/step - loss: 1.4523 - sparse_categorical_crossentropy: 3.2665 - masked_loss: 3.6006 - sparse_categorical_accuracy: 0.4745 - val_loss: 1.9582 - val_sparse_categorical_crossentropy: 3.8975 - val_masked_loss: 4.2264 - val_sparse_categorical_accuracy: 0.3910
# Epoch 8/200
# 393/393 [==============================] - 44s 112ms/step - loss: 1.4165 - sparse_categorical_crossentropy: 3.1756 - masked_loss: 3.5012 - sparse_categorical_accuracy: 0.4824 - val_loss: 1.9276 - val_sparse_categorical_crossentropy: 3.8367 - val_masked_loss: 4.1605 - val_sparse_categorical_accuracy: 0.3984
# Epoch 9/200
# 393/393 [==============================] - 82s 209ms/step - loss: 1.3900 - sparse_categorical_crossentropy: 3.1190 - masked_loss: 3.4381 - sparse_categorical_accuracy: 0.4874 - val_loss: 1.9404 - val_sparse_categorical_crossentropy: 3.8620 - val_masked_loss: 4.1880 - val_sparse_categorical_accuracy: 0.3969
# Epoch 10/200
# 393/393 [==============================] - 52s 133ms/step - loss: 1.3695 - sparse_categorical_crossentropy: 3.0598 - masked_loss: 3.3736 - sparse_categorical_accuracy: 0.4914 - val_loss: 1.9432 - val_sparse_categorical_crossentropy: 3.8677 - val_masked_loss: 4.1941 - val_sparse_categorical_accuracy: 0.3944
# Epoch 11/200
# 393/393 [==============================] - 53s 135ms/step - loss: 1.3447 - sparse_categorical_crossentropy: 3.0052 - masked_loss: 3.3128 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.9539 - val_sparse_categorical_crossentropy: 3.8889 - val_masked_loss: 4.2171 - val_sparse_categorical_accuracy: 0.3992
# Epoch 12/200
# 393/393 [==============================] - 45s 114ms/step - loss: 1.3024 - sparse_categorical_crossentropy: 2.9233 - masked_loss: 3.2226 - sparse_categorical_accuracy: 0.5020 - val_loss: 1.9666 - val_sparse_categorical_crossentropy: 3.9142 - val_masked_loss: 4.2446 - val_sparse_categorical_accuracy: 0.3940
# Epoch 13/200
# 393/393 [==============================] - 53s 135ms/step - loss: 1.2749 - sparse_categorical_crossentropy: 2.8435 - masked_loss: 3.1350 - sparse_categorical_accuracy: 0.5082 - val_loss: 1.9827 - val_sparse_categorical_crossentropy: 3.9463 - val_masked_loss: 4.2793 - val_sparse_categorical_accuracy: 0.3962
# Epoch 14/200
# 393/393 [==============================] - 53s 134ms/step - loss: 1.2326 - sparse_categorical_crossentropy: 2.7701 - masked_loss: 3.0539 - sparse_categorical_accuracy: 0.5131 - val_loss: 1.9977 - val_sparse_categorical_crossentropy: 3.9761 - val_masked_loss: 4.3116 - val_sparse_categorical_accuracy: 0.3968
# Epoch 15/200
# 393/393 [==============================] - 52s 133ms/step - loss: 1.2070 - sparse_categorical_crossentropy: 2.7006 - masked_loss: 2.9771 - sparse_categorical_accuracy: 0.5199 - val_loss: 1.9895 - val_sparse_categorical_crossentropy: 3.9598 - val_masked_loss: 4.2939 - val_sparse_categorical_accuracy: 0.3999
# Epoch 16/200
# 393/393 [==============================] - 42s 108ms/step - loss: 1.1756 - sparse_categorical_crossentropy: 2.6412 - masked_loss: 2.9115 - sparse_categorical_accuracy: 0.5239 - val_loss: 2.0170 - val_sparse_categorical_crossentropy: 4.0146 - val_masked_loss: 4.3534 - val_sparse_categorical_accuracy: 0.3963
# Epoch 17/200
# 393/393 [==============================] - 43s 110ms/step - loss: 1.1450 - sparse_categorical_crossentropy: 2.5650 - masked_loss: 2.8279 - sparse_categorical_accuracy: 0.5307 - val_loss: 2.0336 - val_sparse_categorical_crossentropy: 4.0476 - val_masked_loss: 4.3891 - val_sparse_categorical_accuracy: 0.3956
# Epoch 18/200
# 393/393 [==============================] - 42s 107ms/step - loss: 1.1249 - sparse_categorical_crossentropy: 2.5157 - masked_loss: 2.7731 - sparse_categorical_accuracy: 0.5347 - val_loss: 2.0469 - val_sparse_categorical_crossentropy: 4.0740 - val_masked_loss: 4.4178 - val_sparse_categorical_accuracy: 0.3941
# Epoch 19/200
# 393/393 [==============================] - 52s 133ms/step - loss: 1.0959 - sparse_categorical_crossentropy: 2.4530 - masked_loss: 2.7044 - sparse_categorical_accuracy: 0.5415 - val_loss: 2.0569 - val_sparse_categorical_crossentropy: 4.0940 - val_masked_loss: 4.4395 - val_sparse_categorical_accuracy: 0.3946
# Epoch 20/200
# 393/393 [==============================] - 52s 132ms/step - loss: 1.0700 - sparse_categorical_crossentropy: 2.4018 - masked_loss: 2.6473 - sparse_categorical_accuracy: 0.5458 - val_loss: 2.0693 - val_sparse_categorical_crossentropy: 4.1186 - val_masked_loss: 4.4662 - val_sparse_categorical_accuracy: 0.3951
# Epoch 21/200
# 393/393 [==============================] - 51s 129ms/step - loss: 1.0497 - sparse_categorical_crossentropy: 2.3472 - masked_loss: 2.5880 - sparse_categorical_accuracy: 0.5512 - val_loss: 2.0851 - val_sparse_categorical_crossentropy: 4.1501 - val_masked_loss: 4.5004 - val_sparse_categorical_accuracy: 0.3921
# Epoch 22/200
# 393/393 [==============================] - 41s 105ms/step - loss: 1.0236 - sparse_categorical_crossentropy: 2.3014 - masked_loss: 2.5370 - sparse_categorical_accuracy: 0.5554 - val_loss: 2.1083 - val_sparse_categorical_crossentropy: 4.1964 - val_masked_loss: 4.5505 - val_sparse_categorical_accuracy: 0.3962
# Epoch 23/200
# 393/393 [==============================] - 42s 106ms/step - loss: 1.0068 - sparse_categorical_crossentropy: 2.2505 - masked_loss: 2.4810 - sparse_categorical_accuracy: 0.5613 - val_loss: 2.1159 - val_sparse_categorical_crossentropy: 4.2115 - val_masked_loss: 4.5669 - val_sparse_categorical_accuracy: 0.3925
# Epoch 24/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.9811 - sparse_categorical_crossentropy: 2.2073 - masked_loss: 2.4331 - sparse_categorical_accuracy: 0.5652 - val_loss: 2.1317 - val_sparse_categorical_crossentropy: 4.2429 - val_masked_loss: 4.6010 - val_sparse_categorical_accuracy: 0.3969
# Epoch 25/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.9659 - sparse_categorical_crossentropy: 2.1728 - masked_loss: 2.3954 - sparse_categorical_accuracy: 0.5686 - val_loss: 2.1537 - val_sparse_categorical_crossentropy: 4.2866 - val_masked_loss: 4.6483 - val_sparse_categorical_accuracy: 0.3948
# Epoch 26/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.9483 - sparse_categorical_crossentropy: 2.1256 - masked_loss: 2.3436 - sparse_categorical_accuracy: 0.5742 - val_loss: 2.1706 - val_sparse_categorical_crossentropy: 4.3203 - val_masked_loss: 4.6849 - val_sparse_categorical_accuracy: 0.3953
# Epoch 27/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.9275 - sparse_categorical_crossentropy: 2.0872 - masked_loss: 2.3010 - sparse_categorical_accuracy: 0.5799 - val_loss: 2.1817 - val_sparse_categorical_crossentropy: 4.3424 - val_masked_loss: 4.7088 - val_sparse_categorical_accuracy: 0.3909
# Epoch 28/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.9188 - sparse_categorical_crossentropy: 2.0569 - masked_loss: 2.2677 - sparse_categorical_accuracy: 0.5832 - val_loss: 2.2009 - val_sparse_categorical_crossentropy: 4.3806 - val_masked_loss: 4.7502 - val_sparse_categorical_accuracy: 0.3940
# Epoch 29/200
# 393/393 [==============================] - 50s 127ms/step - loss: 0.8963 - sparse_categorical_crossentropy: 2.0161 - masked_loss: 2.2227 - sparse_categorical_accuracy: 0.5872 - val_loss: 2.2081 - val_sparse_categorical_crossentropy: 4.3949 - val_masked_loss: 4.7658 - val_sparse_categorical_accuracy: 0.3919
# Epoch 30/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.8826 - sparse_categorical_crossentropy: 1.9796 - masked_loss: 2.1821 - sparse_categorical_accuracy: 0.5921 - val_loss: 2.2126 - val_sparse_categorical_crossentropy: 4.4039 - val_masked_loss: 4.7756 - val_sparse_categorical_accuracy: 0.3928
# Epoch 31/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.8716 - sparse_categorical_crossentropy: 1.9524 - masked_loss: 2.1527 - sparse_categorical_accuracy: 0.5955 - val_loss: 2.2326 - val_sparse_categorical_crossentropy: 4.4436 - val_masked_loss: 4.8186 - val_sparse_categorical_accuracy: 0.3934
# Epoch 32/200
# 393/393 [==============================] - 91s 232ms/step - loss: 0.8440 - sparse_categorical_crossentropy: 1.9161 - masked_loss: 2.1123 - sparse_categorical_accuracy: 0.6000 - val_loss: 2.2437 - val_sparse_categorical_crossentropy: 4.4659 - val_masked_loss: 4.8427 - val_sparse_categorical_accuracy: 0.3935
# Epoch 33/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.8398 - sparse_categorical_crossentropy: 1.8876 - masked_loss: 2.0813 - sparse_categorical_accuracy: 0.6036 - val_loss: 2.2685 - val_sparse_categorical_crossentropy: 4.5151 - val_masked_loss: 4.8961 - val_sparse_categorical_accuracy: 0.3921
# Epoch 34/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.8304 - sparse_categorical_crossentropy: 1.8639 - masked_loss: 2.0549 - sparse_categorical_accuracy: 0.6075 - val_loss: 2.2714 - val_sparse_categorical_crossentropy: 4.5209 - val_masked_loss: 4.9024 - val_sparse_categorical_accuracy: 0.3929
# Epoch 35/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.8139 - sparse_categorical_crossentropy: 1.8344 - masked_loss: 2.0223 - sparse_categorical_accuracy: 0.6106 - val_loss: 2.2850 - val_sparse_categorical_crossentropy: 4.5479 - val_masked_loss: 4.9317 - val_sparse_categorical_accuracy: 0.3918
# Epoch 36/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.8069 - sparse_categorical_crossentropy: 1.8044 - masked_loss: 1.9891 - sparse_categorical_accuracy: 0.6146 - val_loss: 2.3102 - val_sparse_categorical_crossentropy: 4.5981 - val_masked_loss: 4.9862 - val_sparse_categorical_accuracy: 0.3903
# Epoch 37/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.7911 - sparse_categorical_crossentropy: 1.7752 - masked_loss: 1.9572 - sparse_categorical_accuracy: 0.6188 - val_loss: 2.3022 - val_sparse_categorical_crossentropy: 4.5821 - val_masked_loss: 4.9689 - val_sparse_categorical_accuracy: 0.3898
# Epoch 38/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.7849 - sparse_categorical_crossentropy: 1.7537 - masked_loss: 1.9334 - sparse_categorical_accuracy: 0.6223 - val_loss: 2.3356 - val_sparse_categorical_crossentropy: 4.6487 - val_masked_loss: 5.0410 - val_sparse_categorical_accuracy: 0.3907
# Epoch 39/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.7704 - sparse_categorical_crossentropy: 1.7239 - masked_loss: 1.9004 - sparse_categorical_accuracy: 0.6268 - val_loss: 2.3334 - val_sparse_categorical_crossentropy: 4.6442 - val_masked_loss: 5.0361 - val_sparse_categorical_accuracy: 0.3901
# Epoch 40/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.7610 - sparse_categorical_crossentropy: 1.7080 - masked_loss: 1.8830 - sparse_categorical_accuracy: 0.6292 - val_loss: 2.3516 - val_sparse_categorical_crossentropy: 4.6806 - val_masked_loss: 5.0756 - val_sparse_categorical_accuracy: 0.3902
# Epoch 41/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.7506 - sparse_categorical_crossentropy: 1.6740 - masked_loss: 1.8456 - sparse_categorical_accuracy: 0.6348 - val_loss: 2.3598 - val_sparse_categorical_crossentropy: 4.6969 - val_masked_loss: 5.0932 - val_sparse_categorical_accuracy: 0.3889
# Epoch 42/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.7398 - sparse_categorical_crossentropy: 1.6639 - masked_loss: 1.8343 - sparse_categorical_accuracy: 0.6355 - val_loss: 2.3729 - val_sparse_categorical_crossentropy: 4.7230 - val_masked_loss: 5.1216 - val_sparse_categorical_accuracy: 0.3883
# Epoch 43/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.7291 - sparse_categorical_crossentropy: 1.6389 - masked_loss: 1.8066 - sparse_categorical_accuracy: 0.6399 - val_loss: 2.3893 - val_sparse_categorical_crossentropy: 4.7555 - val_masked_loss: 5.1568 - val_sparse_categorical_accuracy: 0.3860
# Epoch 44/200
# 393/393 [==============================] - 41s 104ms/step - loss: 0.7160 - sparse_categorical_crossentropy: 1.6133 - masked_loss: 1.7788 - sparse_categorical_accuracy: 0.6435 - val_loss: 2.4070 - val_sparse_categorical_crossentropy: 4.7908 - val_masked_loss: 5.1952 - val_sparse_categorical_accuracy: 0.3875
# Epoch 45/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.7115 - sparse_categorical_crossentropy: 1.5960 - masked_loss: 1.7596 - sparse_categorical_accuracy: 0.6462 - val_loss: 2.4116 - val_sparse_categorical_crossentropy: 4.7999 - val_masked_loss: 5.2050 - val_sparse_categorical_accuracy: 0.3863
# Epoch 46/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.6984 - sparse_categorical_crossentropy: 1.5715 - masked_loss: 1.7325 - sparse_categorical_accuracy: 0.6502 - val_loss: 2.4226 - val_sparse_categorical_crossentropy: 4.8218 - val_masked_loss: 5.2288 - val_sparse_categorical_accuracy: 0.3869
# Epoch 47/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.6924 - sparse_categorical_crossentropy: 1.5510 - masked_loss: 1.7098 - sparse_categorical_accuracy: 0.6533 - val_loss: 2.4176 - val_sparse_categorical_crossentropy: 4.8118 - val_masked_loss: 5.2179 - val_sparse_categorical_accuracy: 0.3874
# Epoch 48/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.6859 - sparse_categorical_crossentropy: 1.5340 - masked_loss: 1.6914 - sparse_categorical_accuracy: 0.6568 - val_loss: 2.4444 - val_sparse_categorical_crossentropy: 4.8652 - val_masked_loss: 5.2758 - val_sparse_categorical_accuracy: 0.3844
# Epoch 49/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.6731 - sparse_categorical_crossentropy: 1.5151 - masked_loss: 1.6701 - sparse_categorical_accuracy: 0.6588 - val_loss: 2.4398 - val_sparse_categorical_crossentropy: 4.8561 - val_masked_loss: 5.2660 - val_sparse_categorical_accuracy: 0.3846
# Epoch 50/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.6685 - sparse_categorical_crossentropy: 1.4966 - masked_loss: 1.6497 - sparse_categorical_accuracy: 0.6631 - val_loss: 2.4678 - val_sparse_categorical_crossentropy: 4.9119 - val_masked_loss: 5.3264 - val_sparse_categorical_accuracy: 0.3837
# Epoch 51/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.6518 - sparse_categorical_crossentropy: 1.4753 - masked_loss: 1.6269 - sparse_categorical_accuracy: 0.6654 - val_loss: 2.4625 - val_sparse_categorical_crossentropy: 4.9013 - val_masked_loss: 5.3150 - val_sparse_categorical_accuracy: 0.3865
# Epoch 52/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.6536 - sparse_categorical_crossentropy: 1.4609 - masked_loss: 1.6103 - sparse_categorical_accuracy: 0.6688 - val_loss: 2.4503 - val_sparse_categorical_crossentropy: 4.8770 - val_masked_loss: 5.2886 - val_sparse_categorical_accuracy: 0.3819
# Epoch 53/200
# 393/393 [==============================] - 50s 128ms/step - loss: 0.6440 - sparse_categorical_crossentropy: 1.4448 - masked_loss: 1.5927 - sparse_categorical_accuracy: 0.6712 - val_loss: 2.4683 - val_sparse_categorical_crossentropy: 4.9127 - val_masked_loss: 5.3273 - val_sparse_categorical_accuracy: 0.3856
# Epoch 54/200
# 393/393 [==============================] - 42s 106ms/step - loss: 0.6360 - sparse_categorical_crossentropy: 1.4288 - masked_loss: 1.5752 - sparse_categorical_accuracy: 0.6741 - val_loss: 2.5077 - val_sparse_categorical_crossentropy: 4.9912 - val_masked_loss: 5.4124 - val_sparse_categorical_accuracy: 0.3800
# Epoch 55/200
# 393/393 [==============================] - 41s 105ms/step - loss: 0.6287 - sparse_categorical_crossentropy: 1.4041 - masked_loss: 1.5480 - sparse_categorical_accuracy: 0.6785 - val_loss: 2.4989 - val_sparse_categorical_crossentropy: 4.9738 - val_masked_loss: 5.3935 - val_sparse_categorical_accuracy: 0.3863
# Epoch 56/200
# 393/393 [==============================] - 50s 129ms/step - loss: 0.6251 - sparse_categorical_crossentropy: 1.4026 - masked_loss: 1.5463 - sparse_categorical_accuracy: 0.6784 - val_loss: 2.5148 - val_sparse_categorical_crossentropy: 5.0053 - val_masked_loss: 5.4277 - val_sparse_categorical_accuracy: 0.3850
# Epoch 57/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.6145 - sparse_categorical_crossentropy: 1.3790 - masked_loss: 1.5202 - sparse_categorical_accuracy: 0.6827 - val_loss: 2.5127 - val_sparse_categorical_crossentropy: 5.0011 - val_masked_loss: 5.4232 - val_sparse_categorical_accuracy: 0.3838
# Epoch 58/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.6084 - sparse_categorical_crossentropy: 1.3645 - masked_loss: 1.5042 - sparse_categorical_accuracy: 0.6853 - val_loss: 2.5282 - val_sparse_categorical_crossentropy: 5.0319 - val_masked_loss: 5.4566 - val_sparse_categorical_accuracy: 0.3814
# Epoch 59/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.6024 - sparse_categorical_crossentropy: 1.3464 - masked_loss: 1.4847 - sparse_categorical_accuracy: 0.6887 - val_loss: 2.5382 - val_sparse_categorical_crossentropy: 5.0519 - val_masked_loss: 5.4783 - val_sparse_categorical_accuracy: 0.3821
# Epoch 60/200
# 393/393 [==============================] - 41s 106ms/step - loss: 0.6054 - sparse_categorical_crossentropy: 1.3438 - masked_loss: 1.4811 - sparse_categorical_accuracy: 0.6887 - val_loss: 2.5323 - val_sparse_categorical_crossentropy: 5.0403 - val_masked_loss: 5.4656 - val_sparse_categorical_accuracy: 0.3844
# Epoch 61/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.5864 - sparse_categorical_crossentropy: 1.3175 - masked_loss: 1.4524 - sparse_categorical_accuracy: 0.6935 - val_loss: 2.5483 - val_sparse_categorical_crossentropy: 5.0721 - val_masked_loss: 5.5001 - val_sparse_categorical_accuracy: 0.3839
# Epoch 62/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5858 - sparse_categorical_crossentropy: 1.3075 - masked_loss: 1.4416 - sparse_categorical_accuracy: 0.6959 - val_loss: 2.5594 - val_sparse_categorical_crossentropy: 5.0941 - val_masked_loss: 5.5240 - val_sparse_categorical_accuracy: 0.3835
# Epoch 63/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5770 - sparse_categorical_crossentropy: 1.2980 - masked_loss: 1.4307 - sparse_categorical_accuracy: 0.6966 - val_loss: 2.5698 - val_sparse_categorical_crossentropy: 5.1147 - val_masked_loss: 5.5464 - val_sparse_categorical_accuracy: 0.3852
# Epoch 64/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.5739 - sparse_categorical_crossentropy: 1.2880 - masked_loss: 1.4202 - sparse_categorical_accuracy: 0.6995 - val_loss: 2.5722 - val_sparse_categorical_crossentropy: 5.1196 - val_masked_loss: 5.5517 - val_sparse_categorical_accuracy: 0.3816
# Epoch 65/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.5664 - sparse_categorical_crossentropy: 1.2668 - masked_loss: 1.3968 - sparse_categorical_accuracy: 0.7023 - val_loss: 2.5654 - val_sparse_categorical_crossentropy: 5.1060 - val_masked_loss: 5.5369 - val_sparse_categorical_accuracy: 0.3828
# Epoch 66/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.5631 - sparse_categorical_crossentropy: 1.2576 - masked_loss: 1.3862 - sparse_categorical_accuracy: 0.7048 - val_loss: 2.5830 - val_sparse_categorical_crossentropy: 5.1411 - val_masked_loss: 5.5750 - val_sparse_categorical_accuracy: 0.3853
# Epoch 67/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.5568 - sparse_categorical_crossentropy: 1.2456 - masked_loss: 1.3735 - sparse_categorical_accuracy: 0.7068 - val_loss: 2.5945 - val_sparse_categorical_crossentropy: 5.1639 - val_masked_loss: 5.5997 - val_sparse_categorical_accuracy: 0.3814
# Epoch 68/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.5523 - sparse_categorical_crossentropy: 1.2429 - masked_loss: 1.3699 - sparse_categorical_accuracy: 0.7072 - val_loss: 2.5942 - val_sparse_categorical_crossentropy: 5.1634 - val_masked_loss: 5.5992 - val_sparse_categorical_accuracy: 0.3829
# Epoch 69/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.5484 - sparse_categorical_crossentropy: 1.2249 - masked_loss: 1.3504 - sparse_categorical_accuracy: 0.7108 - val_loss: 2.6005 - val_sparse_categorical_crossentropy: 5.1758 - val_masked_loss: 5.6126 - val_sparse_categorical_accuracy: 0.3841
# Epoch 70/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.5394 - sparse_categorical_crossentropy: 1.2160 - masked_loss: 1.3405 - sparse_categorical_accuracy: 0.7122 - val_loss: 2.6048 - val_sparse_categorical_crossentropy: 5.1845 - val_masked_loss: 5.6221 - val_sparse_categorical_accuracy: 0.3822
# Epoch 71/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.5369 - sparse_categorical_crossentropy: 1.2046 - masked_loss: 1.3281 - sparse_categorical_accuracy: 0.7147 - val_loss: 2.6042 - val_sparse_categorical_crossentropy: 5.1833 - val_masked_loss: 5.6207 - val_sparse_categorical_accuracy: 0.3801
# Epoch 72/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.5321 - sparse_categorical_crossentropy: 1.1911 - masked_loss: 1.3134 - sparse_categorical_accuracy: 0.7168 - val_loss: 2.6344 - val_sparse_categorical_crossentropy: 5.2433 - val_masked_loss: 5.6859 - val_sparse_categorical_accuracy: 0.3799
# Epoch 73/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.5287 - sparse_categorical_crossentropy: 1.1864 - masked_loss: 1.3078 - sparse_categorical_accuracy: 0.7181 - val_loss: 2.6310 - val_sparse_categorical_crossentropy: 5.2367 - val_masked_loss: 5.6787 - val_sparse_categorical_accuracy: 0.3802
# Epoch 74/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.5229 - sparse_categorical_crossentropy: 1.1761 - masked_loss: 1.2967 - sparse_categorical_accuracy: 0.7198 - val_loss: 2.6352 - val_sparse_categorical_crossentropy: 5.2450 - val_masked_loss: 5.6876 - val_sparse_categorical_accuracy: 0.3815
# Epoch 75/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.5165 - sparse_categorical_crossentropy: 1.1618 - masked_loss: 1.2810 - sparse_categorical_accuracy: 0.7227 - val_loss: 2.6401 - val_sparse_categorical_crossentropy: 5.2547 - val_masked_loss: 5.6982 - val_sparse_categorical_accuracy: 0.3797
# Epoch 76/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5186 - sparse_categorical_crossentropy: 1.1505 - masked_loss: 1.2684 - sparse_categorical_accuracy: 0.7263 - val_loss: 2.6379 - val_sparse_categorical_crossentropy: 5.2504 - val_masked_loss: 5.6936 - val_sparse_categorical_accuracy: 0.3829
# Epoch 77/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.5088 - sparse_categorical_crossentropy: 1.1456 - masked_loss: 1.2632 - sparse_categorical_accuracy: 0.7261 - val_loss: 2.6521 - val_sparse_categorical_crossentropy: 5.2786 - val_masked_loss: 5.7241 - val_sparse_categorical_accuracy: 0.3789
# Epoch 78/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.5070 - sparse_categorical_crossentropy: 1.1344 - masked_loss: 1.2507 - sparse_categorical_accuracy: 0.7278 - val_loss: 2.6590 - val_sparse_categorical_crossentropy: 5.2923 - val_masked_loss: 5.7390 - val_sparse_categorical_accuracy: 0.3801
# Epoch 79/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.5000 - sparse_categorical_crossentropy: 1.1249 - masked_loss: 1.2401 - sparse_categorical_accuracy: 0.7302 - val_loss: 2.6571 - val_sparse_categorical_crossentropy: 5.2887 - val_masked_loss: 5.7350 - val_sparse_categorical_accuracy: 0.3847
# Epoch 80/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.4970 - sparse_categorical_crossentropy: 1.1195 - masked_loss: 1.2339 - sparse_categorical_accuracy: 0.7313 - val_loss: 2.6676 - val_sparse_categorical_crossentropy: 5.3094 - val_masked_loss: 5.7576 - val_sparse_categorical_accuracy: 0.3815
# Epoch 81/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.4969 - sparse_categorical_crossentropy: 1.1121 - masked_loss: 1.2260 - sparse_categorical_accuracy: 0.7325 - val_loss: 2.6771 - val_sparse_categorical_crossentropy: 5.3284 - val_masked_loss: 5.7781 - val_sparse_categorical_accuracy: 0.3803
# Epoch 82/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.4898 - sparse_categorical_crossentropy: 1.0992 - masked_loss: 1.2119 - sparse_categorical_accuracy: 0.7349 - val_loss: 2.6777 - val_sparse_categorical_crossentropy: 5.3296 - val_masked_loss: 5.7795 - val_sparse_categorical_accuracy: 0.3798
# Epoch 83/200
# 393/393 [==============================] - 52s 131ms/step - loss: 0.4878 - sparse_categorical_crossentropy: 1.0905 - masked_loss: 1.2025 - sparse_categorical_accuracy: 0.7369 - val_loss: 2.6864 - val_sparse_categorical_crossentropy: 5.3469 - val_masked_loss: 5.7982 - val_sparse_categorical_accuracy: 0.3816
# Epoch 84/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.4865 - sparse_categorical_crossentropy: 1.0892 - masked_loss: 1.2006 - sparse_categorical_accuracy: 0.7380 - val_loss: 2.6860 - val_sparse_categorical_crossentropy: 5.3462 - val_masked_loss: 5.7974 - val_sparse_categorical_accuracy: 0.3804
# Epoch 85/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.4790 - sparse_categorical_crossentropy: 1.0767 - masked_loss: 1.1871 - sparse_categorical_accuracy: 0.7402 - val_loss: 2.6923 - val_sparse_categorical_crossentropy: 5.3587 - val_masked_loss: 5.8110 - val_sparse_categorical_accuracy: 0.3790
# Epoch 86/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.4756 - sparse_categorical_crossentropy: 1.0673 - masked_loss: 1.1770 - sparse_categorical_accuracy: 0.7421 - val_loss: 2.7032 - val_sparse_categorical_crossentropy: 5.3802 - val_masked_loss: 5.8343 - val_sparse_categorical_accuracy: 0.3802
# Epoch 87/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.4759 - sparse_categorical_crossentropy: 1.0642 - masked_loss: 1.1731 - sparse_categorical_accuracy: 0.7423 - val_loss: 2.7062 - val_sparse_categorical_crossentropy: 5.3863 - val_masked_loss: 5.8409 - val_sparse_categorical_accuracy: 0.3787
# Epoch 88/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.4715 - sparse_categorical_crossentropy: 1.0535 - masked_loss: 1.1618 - sparse_categorical_accuracy: 0.7445 - val_loss: 2.7038 - val_sparse_categorical_crossentropy: 5.3815 - val_masked_loss: 5.8357 - val_sparse_categorical_accuracy: 0.3781
# Epoch 89/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.4657 - sparse_categorical_crossentropy: 1.0477 - masked_loss: 1.1549 - sparse_categorical_accuracy: 0.7451 - val_loss: 2.7185 - val_sparse_categorical_crossentropy: 5.4108 - val_masked_loss: 5.8674 - val_sparse_categorical_accuracy: 0.3800
# Epoch 90/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.4687 - sparse_categorical_crossentropy: 1.0402 - masked_loss: 1.1470 - sparse_categorical_accuracy: 0.7470 - val_loss: 2.7257 - val_sparse_categorical_crossentropy: 5.4251 - val_masked_loss: 5.8829 - val_sparse_categorical_accuracy: 0.3763
# Epoch 91/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4605 - sparse_categorical_crossentropy: 1.0330 - masked_loss: 1.1387 - sparse_categorical_accuracy: 0.7484 - val_loss: 2.7206 - val_sparse_categorical_crossentropy: 5.4150 - val_masked_loss: 5.8721 - val_sparse_categorical_accuracy: 0.3805
# Epoch 92/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.4559 - sparse_categorical_crossentropy: 1.0268 - masked_loss: 1.1320 - sparse_categorical_accuracy: 0.7500 - val_loss: 2.7402 - val_sparse_categorical_crossentropy: 5.4540 - val_masked_loss: 5.9143 - val_sparse_categorical_accuracy: 0.3766
# Epoch 93/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.4555 - sparse_categorical_crossentropy: 1.0229 - masked_loss: 1.1277 - sparse_categorical_accuracy: 0.7506 - val_loss: 2.7344 - val_sparse_categorical_crossentropy: 5.4423 - val_masked_loss: 5.9017 - val_sparse_categorical_accuracy: 0.3784
# Epoch 94/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.4547 - sparse_categorical_crossentropy: 1.0165 - masked_loss: 1.1206 - sparse_categorical_accuracy: 0.7519 - val_loss: 2.7344 - val_sparse_categorical_crossentropy: 5.4425 - val_masked_loss: 5.9018 - val_sparse_categorical_accuracy: 0.3786
# Epoch 95/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.4508 - sparse_categorical_crossentropy: 1.0091 - masked_loss: 1.1126 - sparse_categorical_accuracy: 0.7539 - val_loss: 2.7387 - val_sparse_categorical_crossentropy: 5.4509 - val_masked_loss: 5.9110 - val_sparse_categorical_accuracy: 0.3791
# Epoch 96/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.4424 - sparse_categorical_crossentropy: 1.0009 - masked_loss: 1.1036 - sparse_categorical_accuracy: 0.7550 - val_loss: 2.7376 - val_sparse_categorical_crossentropy: 5.4489 - val_masked_loss: 5.9088 - val_sparse_categorical_accuracy: 0.3777
# Epoch 97/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.4414 - sparse_categorical_crossentropy: 0.9968 - masked_loss: 1.0988 - sparse_categorical_accuracy: 0.7563 - val_loss: 2.7431 - val_sparse_categorical_crossentropy: 5.4598 - val_masked_loss: 5.9206 - val_sparse_categorical_accuracy: 0.3768
# Epoch 98/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.4425 - sparse_categorical_crossentropy: 0.9872 - masked_loss: 1.0885 - sparse_categorical_accuracy: 0.7588 - val_loss: 2.7589 - val_sparse_categorical_crossentropy: 5.4913 - val_masked_loss: 5.9547 - val_sparse_categorical_accuracy: 0.3759
# Epoch 99/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4372 - sparse_categorical_crossentropy: 0.9788 - masked_loss: 1.0793 - sparse_categorical_accuracy: 0.7592 - val_loss: 2.7650 - val_sparse_categorical_crossentropy: 5.5034 - val_masked_loss: 5.9679 - val_sparse_categorical_accuracy: 0.3765
# Epoch 100/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.4353 - sparse_categorical_crossentropy: 0.9771 - masked_loss: 1.0771 - sparse_categorical_accuracy: 0.7596 - val_loss: 2.7693 - val_sparse_categorical_crossentropy: 5.5119 - val_masked_loss: 5.9771 - val_sparse_categorical_accuracy: 0.3784
# Epoch 101/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.4344 - sparse_categorical_crossentropy: 0.9745 - masked_loss: 1.0743 - sparse_categorical_accuracy: 0.7613 - val_loss: 2.7575 - val_sparse_categorical_crossentropy: 5.4884 - val_masked_loss: 5.9516 - val_sparse_categorical_accuracy: 0.3783
# Epoch 102/200
# 393/393 [==============================] - 52s 134ms/step - loss: 0.4275 - sparse_categorical_crossentropy: 0.9627 - masked_loss: 1.0615 - sparse_categorical_accuracy: 0.7632 - val_loss: 2.7671 - val_sparse_categorical_crossentropy: 5.5075 - val_masked_loss: 5.9724 - val_sparse_categorical_accuracy: 0.3785
# Epoch 103/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4298 - sparse_categorical_crossentropy: 0.9618 - masked_loss: 1.0603 - sparse_categorical_accuracy: 0.7633 - val_loss: 2.7671 - val_sparse_categorical_crossentropy: 5.5074 - val_masked_loss: 5.9723 - val_sparse_categorical_accuracy: 0.3783
# Epoch 104/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4248 - sparse_categorical_crossentropy: 0.9544 - masked_loss: 1.0523 - sparse_categorical_accuracy: 0.7646 - val_loss: 2.7751 - val_sparse_categorical_crossentropy: 5.5235 - val_masked_loss: 5.9897 - val_sparse_categorical_accuracy: 0.3789
# Epoch 105/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4184 - sparse_categorical_crossentropy: 0.9439 - masked_loss: 1.0406 - sparse_categorical_accuracy: 0.7679 - val_loss: 2.7815 - val_sparse_categorical_crossentropy: 5.5363 - val_masked_loss: 6.0035 - val_sparse_categorical_accuracy: 0.3773
# Epoch 106/200
# 393/393 [==============================] - 91s 233ms/step - loss: 0.4202 - sparse_categorical_crossentropy: 0.9422 - masked_loss: 1.0388 - sparse_categorical_accuracy: 0.7669 - val_loss: 2.7884 - val_sparse_categorical_crossentropy: 5.5498 - val_masked_loss: 6.0183 - val_sparse_categorical_accuracy: 0.3772
# Epoch 107/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.4172 - sparse_categorical_crossentropy: 0.9364 - masked_loss: 1.0322 - sparse_categorical_accuracy: 0.7686 - val_loss: 2.8023 - val_sparse_categorical_crossentropy: 5.5776 - val_masked_loss: 6.0484 - val_sparse_categorical_accuracy: 0.3768
# Epoch 108/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.4156 - sparse_categorical_crossentropy: 0.9280 - masked_loss: 1.0231 - sparse_categorical_accuracy: 0.7704 - val_loss: 2.8039 - val_sparse_categorical_crossentropy: 5.5808 - val_masked_loss: 6.0518 - val_sparse_categorical_accuracy: 0.3763
# Epoch 109/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4118 - sparse_categorical_crossentropy: 0.9237 - masked_loss: 1.0185 - sparse_categorical_accuracy: 0.7709 - val_loss: 2.8134 - val_sparse_categorical_crossentropy: 5.5997 - val_masked_loss: 6.0723 - val_sparse_categorical_accuracy: 0.3791
# Epoch 110/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.4152 - sparse_categorical_crossentropy: 0.9228 - masked_loss: 1.0175 - sparse_categorical_accuracy: 0.7716 - val_loss: 2.7976 - val_sparse_categorical_crossentropy: 5.5683 - val_masked_loss: 6.0383 - val_sparse_categorical_accuracy: 0.3784
# Epoch 111/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.4083 - sparse_categorical_crossentropy: 0.9188 - masked_loss: 1.0131 - sparse_categorical_accuracy: 0.7729 - val_loss: 2.8056 - val_sparse_categorical_crossentropy: 5.5841 - val_masked_loss: 6.0554 - val_sparse_categorical_accuracy: 0.3770
# Epoch 112/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.4066 - sparse_categorical_crossentropy: 0.9139 - masked_loss: 1.0077 - sparse_categorical_accuracy: 0.7733 - val_loss: 2.8075 - val_sparse_categorical_crossentropy: 5.5878 - val_masked_loss: 6.0595 - val_sparse_categorical_accuracy: 0.3777
# Epoch 113/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.4062 - sparse_categorical_crossentropy: 0.9091 - masked_loss: 1.0020 - sparse_categorical_accuracy: 0.7743 - val_loss: 2.8201 - val_sparse_categorical_crossentropy: 5.6130 - val_masked_loss: 6.0868 - val_sparse_categorical_accuracy: 0.3766
# Epoch 114/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.4044 - sparse_categorical_crossentropy: 0.9027 - masked_loss: 0.9952 - sparse_categorical_accuracy: 0.7762 - val_loss: 2.8141 - val_sparse_categorical_crossentropy: 5.6011 - val_masked_loss: 6.0739 - val_sparse_categorical_accuracy: 0.3773
# Epoch 115/200
# 393/393 [==============================] - 51s 130ms/step - loss: 0.3954 - sparse_categorical_crossentropy: 0.8978 - masked_loss: 0.9900 - sparse_categorical_accuracy: 0.7765 - val_loss: 2.8265 - val_sparse_categorical_crossentropy: 5.6258 - val_masked_loss: 6.1006 - val_sparse_categorical_accuracy: 0.3751
# Epoch 116/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.3975 - sparse_categorical_crossentropy: 0.8894 - masked_loss: 0.9807 - sparse_categorical_accuracy: 0.7785 - val_loss: 2.8317 - val_sparse_categorical_crossentropy: 5.6360 - val_masked_loss: 6.1117 - val_sparse_categorical_accuracy: 0.3767
# Epoch 117/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3958 - sparse_categorical_crossentropy: 0.8869 - masked_loss: 0.9779 - sparse_categorical_accuracy: 0.7794 - val_loss: 2.8353 - val_sparse_categorical_crossentropy: 5.6432 - val_masked_loss: 6.1195 - val_sparse_categorical_accuracy: 0.3768
# Epoch 118/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.3962 - sparse_categorical_crossentropy: 0.8812 - masked_loss: 0.9713 - sparse_categorical_accuracy: 0.7813 - val_loss: 2.8383 - val_sparse_categorical_crossentropy: 5.6492 - val_masked_loss: 6.1260 - val_sparse_categorical_accuracy: 0.3749
# Epoch 119/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.3892 - sparse_categorical_crossentropy: 0.8760 - masked_loss: 0.9659 - sparse_categorical_accuracy: 0.7809 - val_loss: 2.8405 - val_sparse_categorical_crossentropy: 5.6535 - val_masked_loss: 6.1307 - val_sparse_categorical_accuracy: 0.3748
# Epoch 120/200
# 393/393 [==============================] - 51s 131ms/step - loss: 0.3873 - sparse_categorical_crossentropy: 0.8740 - masked_loss: 0.9636 - sparse_categorical_accuracy: 0.7815 - val_loss: 2.8655 - val_sparse_categorical_crossentropy: 5.7033 - val_masked_loss: 6.1847 - val_sparse_categorical_accuracy: 0.3763
# Epoch 121/200
# 393/393 [==============================] - 42s 107ms/step - loss: 0.3859 - sparse_categorical_crossentropy: 0.8678 - masked_loss: 0.9570 - sparse_categorical_accuracy: 0.7840 - val_loss: 2.8413 - val_sparse_categorical_crossentropy: 5.6553 - val_masked_loss: 6.1326 - val_sparse_categorical_accuracy: 0.3738
# Epoch 122/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3868 - sparse_categorical_crossentropy: 0.8691 - masked_loss: 0.9580 - sparse_categorical_accuracy: 0.7840 - val_loss: 2.8511 - val_sparse_categorical_crossentropy: 5.6746 - val_masked_loss: 6.1536 - val_sparse_categorical_accuracy: 0.3753
# Epoch 123/200
# 393/393 [==============================] - 42s 108ms/step - loss: 0.3850 - sparse_categorical_crossentropy: 0.8626 - masked_loss: 0.9511 - sparse_categorical_accuracy: 0.7848 - val_loss: 2.8524 - val_sparse_categorical_crossentropy: 5.6772 - val_masked_loss: 6.1564 - val_sparse_categorical_accuracy: 0.3765
# Epoch 124/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.3817 - sparse_categorical_crossentropy: 0.8592 - masked_loss: 0.9472 - sparse_categorical_accuracy: 0.7862 - val_loss: 2.8603 - val_sparse_categorical_crossentropy: 5.6930 - val_masked_loss: 6.1735 - val_sparse_categorical_accuracy: 0.3769
# Epoch 125/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3818 - sparse_categorical_crossentropy: 0.8526 - masked_loss: 0.9400 - sparse_categorical_accuracy: 0.7870 - val_loss: 2.8513 - val_sparse_categorical_crossentropy: 5.6751 - val_masked_loss: 6.1540 - val_sparse_categorical_accuracy: 0.3771
# Epoch 126/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.3791 - sparse_categorical_crossentropy: 0.8507 - masked_loss: 0.9379 - sparse_categorical_accuracy: 0.7862 - val_loss: 2.8552 - val_sparse_categorical_crossentropy: 5.6828 - val_masked_loss: 6.1625 - val_sparse_categorical_accuracy: 0.3765
# Epoch 127/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3789 - sparse_categorical_crossentropy: 0.8452 - masked_loss: 0.9320 - sparse_categorical_accuracy: 0.7887 - val_loss: 2.8722 - val_sparse_categorical_crossentropy: 5.7167 - val_masked_loss: 6.1992 - val_sparse_categorical_accuracy: 0.3756
# Epoch 128/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3752 - sparse_categorical_crossentropy: 0.8445 - masked_loss: 0.9311 - sparse_categorical_accuracy: 0.7889 - val_loss: 2.8619 - val_sparse_categorical_crossentropy: 5.6961 - val_masked_loss: 6.1769 - val_sparse_categorical_accuracy: 0.3776
# Epoch 129/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.3750 - sparse_categorical_crossentropy: 0.8385 - masked_loss: 0.9242 - sparse_categorical_accuracy: 0.7903 - val_loss: 2.8669 - val_sparse_categorical_crossentropy: 5.7062 - val_masked_loss: 6.1879 - val_sparse_categorical_accuracy: 0.3761
# Epoch 130/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3721 - sparse_categorical_crossentropy: 0.8299 - masked_loss: 0.9153 - sparse_categorical_accuracy: 0.7920 - val_loss: 2.8813 - val_sparse_categorical_crossentropy: 5.7348 - val_masked_loss: 6.2189 - val_sparse_categorical_accuracy: 0.3741
# Epoch 131/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3708 - sparse_categorical_crossentropy: 0.8333 - masked_loss: 0.9185 - sparse_categorical_accuracy: 0.7916 - val_loss: 2.8671 - val_sparse_categorical_crossentropy: 5.7065 - val_masked_loss: 6.1882 - val_sparse_categorical_accuracy: 0.3751
# Epoch 132/200
# 393/393 [==============================] - 73s 186ms/step - loss: 0.3692 - sparse_categorical_crossentropy: 0.8289 - masked_loss: 0.9139 - sparse_categorical_accuracy: 0.7921 - val_loss: 2.8878 - val_sparse_categorical_crossentropy: 5.7477 - val_masked_loss: 6.2328 - val_sparse_categorical_accuracy: 0.3762
# Epoch 133/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.3674 - sparse_categorical_crossentropy: 0.8223 - masked_loss: 0.9068 - sparse_categorical_accuracy: 0.7934 - val_loss: 2.8750 - val_sparse_categorical_crossentropy: 5.7222 - val_masked_loss: 6.2052 - val_sparse_categorical_accuracy: 0.3747
# Epoch 134/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3652 - sparse_categorical_crossentropy: 0.8203 - masked_loss: 0.9045 - sparse_categorical_accuracy: 0.7942 - val_loss: 2.8874 - val_sparse_categorical_crossentropy: 5.7470 - val_masked_loss: 6.2321 - val_sparse_categorical_accuracy: 0.3723
# Epoch 135/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3595 - sparse_categorical_crossentropy: 0.8131 - masked_loss: 0.8964 - sparse_categorical_accuracy: 0.7960 - val_loss: 2.8888 - val_sparse_categorical_crossentropy: 5.7497 - val_masked_loss: 6.2350 - val_sparse_categorical_accuracy: 0.3734
# Epoch 136/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.3634 - sparse_categorical_crossentropy: 0.8152 - masked_loss: 0.8986 - sparse_categorical_accuracy: 0.7960 - val_loss: 2.8922 - val_sparse_categorical_crossentropy: 5.7565 - val_masked_loss: 6.2424 - val_sparse_categorical_accuracy: 0.3747
# Epoch 137/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.3616 - sparse_categorical_crossentropy: 0.8053 - masked_loss: 0.8880 - sparse_categorical_accuracy: 0.7981 - val_loss: 2.8862 - val_sparse_categorical_crossentropy: 5.7446 - val_masked_loss: 6.2294 - val_sparse_categorical_accuracy: 0.3765
# Epoch 138/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.3617 - sparse_categorical_crossentropy: 0.8085 - masked_loss: 0.8916 - sparse_categorical_accuracy: 0.7966 - val_loss: 2.8952 - val_sparse_categorical_crossentropy: 5.7624 - val_masked_loss: 6.2488 - val_sparse_categorical_accuracy: 0.3753
# Epoch 139/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3561 - sparse_categorical_crossentropy: 0.7974 - masked_loss: 0.8792 - sparse_categorical_accuracy: 0.7995 - val_loss: 2.9016 - val_sparse_categorical_crossentropy: 5.7752 - val_masked_loss: 6.2627 - val_sparse_categorical_accuracy: 0.3749
# Epoch 140/200
# 393/393 [==============================] - 53s 136ms/step - loss: 0.3570 - sparse_categorical_crossentropy: 0.7986 - masked_loss: 0.8803 - sparse_categorical_accuracy: 0.7994 - val_loss: 2.9110 - val_sparse_categorical_crossentropy: 5.7939 - val_masked_loss: 6.2829 - val_sparse_categorical_accuracy: 0.3749
# Epoch 141/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.3547 - sparse_categorical_crossentropy: 0.7951 - masked_loss: 0.8767 - sparse_categorical_accuracy: 0.7999 - val_loss: 2.9008 - val_sparse_categorical_crossentropy: 5.7737 - val_masked_loss: 6.2610 - val_sparse_categorical_accuracy: 0.3752
# Epoch 142/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3504 - sparse_categorical_crossentropy: 0.7877 - masked_loss: 0.8687 - sparse_categorical_accuracy: 0.8016 - val_loss: 2.9063 - val_sparse_categorical_crossentropy: 5.7846 - val_masked_loss: 6.2729 - val_sparse_categorical_accuracy: 0.3745
# Epoch 143/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.3507 - sparse_categorical_crossentropy: 0.7878 - masked_loss: 0.8685 - sparse_categorical_accuracy: 0.8012 - val_loss: 2.9132 - val_sparse_categorical_crossentropy: 5.7984 - val_masked_loss: 6.2878 - val_sparse_categorical_accuracy: 0.3752
# Epoch 144/200
# 393/393 [==============================] - 52s 134ms/step - loss: 0.3484 - sparse_categorical_crossentropy: 0.7838 - masked_loss: 0.8643 - sparse_categorical_accuracy: 0.8029 - val_loss: 2.9060 - val_sparse_categorical_crossentropy: 5.7840 - val_masked_loss: 6.2722 - val_sparse_categorical_accuracy: 0.3765
# Epoch 145/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.3503 - sparse_categorical_crossentropy: 0.7835 - masked_loss: 0.8635 - sparse_categorical_accuracy: 0.8025 - val_loss: 2.9221 - val_sparse_categorical_crossentropy: 5.8161 - val_masked_loss: 6.3070 - val_sparse_categorical_accuracy: 0.3738
# Epoch 146/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.3477 - sparse_categorical_crossentropy: 0.7784 - masked_loss: 0.8584 - sparse_categorical_accuracy: 0.8034 - val_loss: 2.9176 - val_sparse_categorical_crossentropy: 5.8070 - val_masked_loss: 6.2971 - val_sparse_categorical_accuracy: 0.3727
# Epoch 147/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3478 - sparse_categorical_crossentropy: 0.7752 - masked_loss: 0.8546 - sparse_categorical_accuracy: 0.8043 - val_loss: 2.9220 - val_sparse_categorical_crossentropy: 5.8159 - val_masked_loss: 6.3068 - val_sparse_categorical_accuracy: 0.3751
# Epoch 148/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3448 - sparse_categorical_crossentropy: 0.7746 - masked_loss: 0.8540 - sparse_categorical_accuracy: 0.8046 - val_loss: 2.9209 - val_sparse_categorical_crossentropy: 5.8135 - val_masked_loss: 6.3042 - val_sparse_categorical_accuracy: 0.3748
# Epoch 149/200
# ...
# Epoch 152/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3379 - sparse_categorical_crossentropy: 0.7592 - masked_loss: 0.8373 - sparse_categorical_accuracy: 0.8075 - val_loss: 2.9291 - val_sparse_categorical_crossentropy: 5.8300 - val_masked_loss: 6.3220 - val_sparse_categorical_accuracy: 0.3713
# Epoch 153/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3388 - sparse_categorical_crossentropy: 0.7584 - masked_loss: 0.8358 - sparse_categorical_accuracy: 0.8080 - val_loss: 2.9300 - val_sparse_categorical_crossentropy: 5.8318 - val_masked_loss: 6.3240 - val_sparse_categorical_accuracy: 0.3750
# Epoch 154/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.3357 - sparse_categorical_crossentropy: 0.7503 - masked_loss: 0.8272 - sparse_categorical_accuracy: 0.8103 - val_loss: 2.9425 - val_sparse_categorical_crossentropy: 5.8565 - val_masked_loss: 6.3509 - val_sparse_categorical_accuracy: 0.3730
# Epoch 155/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.3327 - sparse_categorical_crossentropy: 0.7510 - masked_loss: 0.8281 - sparse_categorical_accuracy: 0.8100 - val_loss: 2.9519 - val_sparse_categorical_crossentropy: 5.8754 - val_masked_loss: 6.3713 - val_sparse_categorical_accuracy: 0.3757
# Epoch 156/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3366 - sparse_categorical_crossentropy: 0.7494 - masked_loss: 0.8263 - sparse_categorical_accuracy: 0.8096 - val_loss: 2.9336 - val_sparse_categorical_crossentropy: 5.8389 - val_masked_loss: 6.3317 - val_sparse_categorical_accuracy: 0.3751
# Epoch 157/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.3295 - sparse_categorical_crossentropy: 0.7452 - masked_loss: 0.8217 - sparse_categorical_accuracy: 0.8119 - val_loss: 2.9336 - val_sparse_categorical_crossentropy: 5.8389 - val_masked_loss: 6.3317 - val_sparse_categorical_accuracy: 0.3741
# Epoch 158/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.3303 - sparse_categorical_crossentropy: 0.7388 - masked_loss: 0.8143 - sparse_categorical_accuracy: 0.8126 - val_loss: 2.9528 - val_sparse_categorical_crossentropy: 5.8771 - val_masked_loss: 6.3732 - val_sparse_categorical_accuracy: 0.3749
# Epoch 159/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3299 - sparse_categorical_crossentropy: 0.7388 - masked_loss: 0.8144 - sparse_categorical_accuracy: 0.8132 - val_loss: 2.9546 - val_sparse_categorical_crossentropy: 5.8807 - val_masked_loss: 6.3771 - val_sparse_categorical_accuracy: 0.3739
# Epoch 160/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.3298 - sparse_categorical_crossentropy: 0.7369 - masked_loss: 0.8127 - sparse_categorical_accuracy: 0.8132 - val_loss: 2.9553 - val_sparse_categorical_crossentropy: 5.8822 - val_masked_loss: 6.3786 - val_sparse_categorical_accuracy: 0.3741
# Epoch 161/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3275 - sparse_categorical_crossentropy: 0.7350 - masked_loss: 0.8103 - sparse_categorical_accuracy: 0.8141 - val_loss: 2.9587 - val_sparse_categorical_crossentropy: 5.8888 - val_masked_loss: 6.3859 - val_sparse_categorical_accuracy: 0.3736
# Epoch 162/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.3262 - sparse_categorical_crossentropy: 0.7311 - masked_loss: 0.8061 - sparse_categorical_accuracy: 0.8139 - val_loss: 2.9524 - val_sparse_categorical_crossentropy: 5.8762 - val_masked_loss: 6.3722 - val_sparse_categorical_accuracy: 0.3751
# Epoch 163/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.3214 - sparse_categorical_crossentropy: 0.7235 - masked_loss: 0.7979 - sparse_categorical_accuracy: 0.8159 - val_loss: 2.9538 - val_sparse_categorical_crossentropy: 5.8791 - val_masked_loss: 6.3754 - val_sparse_categorical_accuracy: 0.3749
# Epoch 164/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.3244 - sparse_categorical_crossentropy: 0.7294 - masked_loss: 0.8040 - sparse_categorical_accuracy: 0.8149 - val_loss: 2.9602 - val_sparse_categorical_crossentropy: 5.8918 - val_masked_loss: 6.3891 - val_sparse_categorical_accuracy: 0.3752
# Epoch 165/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.3240 - sparse_categorical_crossentropy: 0.7212 - masked_loss: 0.7950 - sparse_categorical_accuracy: 0.8174 - val_loss: 2.9630 - val_sparse_categorical_crossentropy: 5.8974 - val_masked_loss: 6.3951 - val_sparse_categorical_accuracy: 0.3755
# Epoch 166/200
# 393/393 [==============================] - 52s 132ms/step - loss: 0.3202 - sparse_categorical_crossentropy: 0.7208 - masked_loss: 0.7947 - sparse_categorical_accuracy: 0.8157 - val_loss: 2.9518 - val_sparse_categorical_crossentropy: 5.8752 - val_masked_loss: 6.3710 - val_sparse_categorical_accuracy: 0.3765
# Epoch 167/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.3201 - sparse_categorical_crossentropy: 0.7103 - masked_loss: 0.7832 - sparse_categorical_accuracy: 0.8189 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 168/200
# 393/393 [==============================] - 44s 112ms/step - loss: 0.2809 - sparse_categorical_crossentropy: 0.6348 - masked_loss: 0.6997 - sparse_categorical_accuracy: 0.8363 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 169/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.2716 - sparse_categorical_crossentropy: 0.6084 - masked_loss: 0.6709 - sparse_categorical_accuracy: 0.8430 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 170/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.2688 - sparse_categorical_crossentropy: 0.6024 - masked_loss: 0.6640 - sparse_categorical_accuracy: 0.8442 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 171/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2680 - sparse_categorical_crossentropy: 0.6049 - masked_loss: 0.6669 - sparse_categorical_accuracy: 0.8434 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 172/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2718 - sparse_categorical_crossentropy: 0.6078 - masked_loss: 0.6701 - sparse_categorical_accuracy: 0.8428 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 173/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2691 - sparse_categorical_crossentropy: 0.6032 - masked_loss: 0.6649 - sparse_categorical_accuracy: 0.8444 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 174/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2694 - sparse_categorical_crossentropy: 0.6070 - masked_loss: 0.6695 - sparse_categorical_accuracy: 0.8429 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 175/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2724 - sparse_categorical_crossentropy: 0.6084 - masked_loss: 0.6706 - sparse_categorical_accuracy: 0.8425 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 176/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2704 - sparse_categorical_crossentropy: 0.6066 - masked_loss: 0.6687 - sparse_categorical_accuracy: 0.8435 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 177/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2698 - sparse_categorical_crossentropy: 0.6013 - masked_loss: 0.6632 - sparse_categorical_accuracy: 0.8442 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 178/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.2713 - sparse_categorical_crossentropy: 0.6086 - masked_loss: 0.6708 - sparse_categorical_accuracy: 0.8432 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 179/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2710 - sparse_categorical_crossentropy: 0.6077 - masked_loss: 0.6701 - sparse_categorical_accuracy: 0.8428 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 180/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.2706 - sparse_categorical_crossentropy: 0.6026 - masked_loss: 0.6644 - sparse_categorical_accuracy: 0.8443 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 181/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2705 - sparse_categorical_crossentropy: 0.6037 - masked_loss: 0.6655 - sparse_categorical_accuracy: 0.8437 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 182/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.2693 - sparse_categorical_crossentropy: 0.6033 - masked_loss: 0.6652 - sparse_categorical_accuracy: 0.8443 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 183/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2745 - sparse_categorical_crossentropy: 0.6115 - masked_loss: 0.6741 - sparse_categorical_accuracy: 0.8413 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 184/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2679 - sparse_categorical_crossentropy: 0.6005 - masked_loss: 0.6623 - sparse_categorical_accuracy: 0.8455 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 185/200
# 393/393 [==============================] - 43s 109ms/step - loss: 0.2728 - sparse_categorical_crossentropy: 0.6092 - masked_loss: 0.6712 - sparse_categorical_accuracy: 0.8427 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 186/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.2689 - sparse_categorical_crossentropy: 0.6041 - masked_loss: 0.6663 - sparse_categorical_accuracy: 0.8438 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 187/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.2699 - sparse_categorical_crossentropy: 0.6052 - masked_loss: 0.6672 - sparse_categorical_accuracy: 0.8431 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 188/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2723 - sparse_categorical_crossentropy: 0.6090 - masked_loss: 0.6715 - sparse_categorical_accuracy: 0.8425 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 189/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2700 - sparse_categorical_crossentropy: 0.6014 - masked_loss: 0.6630 - sparse_categorical_accuracy: 0.8448 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 190/200
# 393/393 [==============================] - 43s 110ms/step - loss: 0.2687 - sparse_categorical_crossentropy: 0.6066 - masked_loss: 0.6688 - sparse_categorical_accuracy: 0.8429 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 191/200
# 393/393 [==============================] - 43s 111ms/step - loss: 0.2707 - sparse_categorical_crossentropy: 0.6059 - masked_loss: 0.6680 - sparse_categorical_accuracy: 0.8436 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 192/200
# 393/393 [==============================] - 43s 108ms/step - loss: 0.2699 - sparse_categorical_crossentropy: 0.6050 - masked_loss: 0.6671 - sparse_categorical_accuracy: 0.8438 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 193/200
# 393/393 [==============================] - 82s 210ms/step - loss: 0.2680 - sparse_categorical_crossentropy: 0.6048 - masked_loss: 0.6669 - sparse_categorical_accuracy: 0.8441 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 194/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2715 - sparse_categorical_crossentropy: 0.6035 - masked_loss: 0.6655 - sparse_categorical_accuracy: 0.8445 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 195/200
# 393/393 [==============================] - 53s 134ms/step - loss: 0.2709 - sparse_categorical_crossentropy: 0.6096 - masked_loss: 0.6720 - sparse_categorical_accuracy: 0.8420 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 196/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.2684 - sparse_categorical_crossentropy: 0.6029 - masked_loss: 0.6646 - sparse_categorical_accuracy: 0.8439 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 197/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.2706 - sparse_categorical_crossentropy: 0.6059 - masked_loss: 0.6682 - sparse_categorical_accuracy: 0.8441 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 198/200
# 393/393 [==============================] - 44s 111ms/step - loss: 0.2703 - sparse_categorical_crossentropy: 0.6058 - masked_loss: 0.6679 - sparse_categorical_accuracy: 0.8439 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 199/200
# 393/393 [==============================] - 52s 133ms/step - loss: 0.2729 - sparse_categorical_crossentropy: 0.6073 - masked_loss: 0.6696 - sparse_categorical_accuracy: 0.8438 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746
# Epoch 200/200
# 393/393 [==============================] - 53s 135ms/step - loss: 0.2708 - sparse_categorical_crossentropy: 0.6054 - masked_loss: 0.6675 - sparse_categorical_accuracy: 0.8441 - val_loss: 2.9631 - val_sparse_categorical_crossentropy: 5.8977 - val_masked_loss: 6.3955 - val_sparse_categorical_accuracy: 0.3746

# %% [markdown]
# Prediction

# %%
# Возьмем первые 10 значений данных
for i in range(10):
  translation = [tokenizer_full.vocab_size]

  # Пройдём по каждому токену (максимум 30) и сделаем предикт
  for _ in range(30):
    predict = model.predict([questions_batch[i:i+1],np.asarray([translation])]) # Делаем предикт
    translation.append(np.argmax(predict[-1,-1]))        # Ищем индекс токена
    if translation[-1] == tokenizer_full.vocab_size + 1:  # Если предсказан выходной тег, то заканчиваем цикл
      break
  
  # Запишем реальный ответ
  real_translation = []
  for w in answers_batch[:,1:][i].numpy():
    if w == tokenizer_full.vocab_size + 1:
      break
    real_translation.append(w)

  # Запишем вопрос
  real_text = []
  for w in questions_batch[:,1:][i].numpy():
    if w == tokenizer_full.vocab_size + 1:
      break
    real_text.append(w)
  
  print('Вопрос:             ', tokenizer_full.decode(real_text))
  print('Реальный ответ:     ', tokenizer_full.decode(real_translation))
  print('Ответ трансформера: ', tokenizer_full.decode(translation[1:-1]))
  print("")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# Вопрос:              Why do you think the Cape is your favorite place in the world ?
# Реальный ответ:      None of the above choices .
# Ответ трансформера:  I am seriously proud of how much money is doing the way to hurt and a horrible up doing it .
#
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# Вопрос:              Why did the writer go horseback riding ?
# Реальный ответ:      Because someone might have eaten something bad .
# Ответ трансформера:  None of the above choices .
#
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# Вопрос:              What may have caused you to meet your husband ?
# Реальный ответ:      Academics led us together .
# Ответ трансформера:  I made a joke that could 's almost worked so my done the man great music to go to school .
#
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# Вопрос:              What might be different if the install did n't fail ?
# Реальный ответ:      They would have installed vista prem again
# Ответ трансформера:  The family could become a party and Expo
#
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# Вопрос:              Why are they talking about their growth as a company ?
# Реальный ответ:      They want to cahnge into a developement company from a PHP
# Ответ трансформера:  The wind had many people over for them for the location .
#
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# Вопрос:              What may be your reason for dumping your current boyfriend ?
# Реальный ответ:      I had a dream where my partner dumped me .
# Ответ трансформера:  I knew we had the before we put it .
#
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# Вопрос:              What may be the reason for your exhaustion before work ?
# Реальный ответ:      I had slept in every day .
# Ответ трансформера:  None of the above choices .
#
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# Вопрос:              What may have caused you to choose the Hearst Castle as your hotel ?
# Реальный ответ:      Josh got us a free room at that cool hotel .
# Ответ трансформера:  The customer was in a hurry
#
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# Вопрос:              Why did they go to look for truffles ?
# Реальный ответ:      Because a woman said that she knew just the place .
# Ответ трансформера:  Because they wanted to extend thoughts and prayers to the families .
#
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# Вопрос:              What has caused you to be so upset and fuming with anger ?
# Реальный ответ:      Someone has continued to annoy me for a long time now
# Ответ трансформера:  He would rather have had a hard time walking around with them .

# %% [markdown]
# Ответы трансформера близкие по смыслу, но не точные. Данных достаточно мало, но результат не плохой.
